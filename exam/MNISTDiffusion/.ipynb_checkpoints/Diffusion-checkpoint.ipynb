# %%
# %env PATH=/usr/local/cuda-11.8/bin:$PATH
# %env LD_LIBRARY_PATH=/usr/local/cuda-11.8/lib64:$LD_LIBRARY_PATH
# Out:
# env: PATH=/usr/local/cuda-11.8/bin:$PATH
# env: LD_LIBRARY_PATH=/usr/local/cuda-11.8/lib64:$LD_LIBRARY_PATH

# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torchvision.utils import save_image
from torch.utils.data import DataLoader
from torch.optim import AdamW
from torch.optim.lr_scheduler import OneCycleLR
from model import MNISTDiffusion
from utils import ExponentialMovingAverage
import os
import math
from tqdm import tqdm

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
print(torch.backends.cudnn.version())
# Out:
# 2.0.0+cu117
# True
# 11.7
# 8900

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
print(torch.backends.cudnn.version())
# Out:
# 2.0.0+cu117
# True
# 11.7
# 8900

# %%
use_cuda = True if torch.cuda.is_available() else False
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
batch_size = 128
epochs = 50
lr = 0.001
n_samples = 36
model_base_dim = 64
model_ema_steps = 10
model_ema_decay = 0.995
log_freq = 10
no_clip = True
timesteps = 1000
# Out:
# cuda

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False, transform=transforms.ToTensor()),
    batch_size=batch_size, shuffle=True, **kwargs)

# %%
model = MNISTDiffusion(timesteps=timesteps,
            image_size=28,
            in_channels=1,
            base_dim=model_base_dim,
            dim_mults=[2,4]).to(device)

# %%
#torchvision ema setting
#https://github.com/pytorch/vision/blob/main/references/classification/train.py#L317
adjust = 1 * batch_size * model_ema_steps / epochs
alpha = 1.0 - model_ema_decay
alpha = min(1.0, alpha * adjust)
model_ema = ExponentialMovingAverage(model, device=device, decay=1.0 - alpha)

# %%
optimizer = AdamW(model.parameters(), lr=lr)
scheduler = OneCycleLR(optimizer, lr, total_steps=epochs*len(train_loader), pct_start=0.25, anneal_strategy='cos')
loss_fn = nn.MSELoss(reduction='mean')

# %%
global_steps=0
for i in range(epochs):
    model.train()
    for j, (image,target) in enumerate(train_loader):
        noise=torch.randn_like(image).to(device)
        image=image.to(device)
        pred=model(image,noise)
        loss=loss_fn(pred,noise)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()
        
        if global_steps % model_ema_steps==0:
            model_ema.update_parameters(model)
            
        global_steps+=1
        if j % log_freq==0:
            print("Epoch[{}/{}],Step[{}/{}],loss:{:.5f},lr:{:.5f}".format(i+1,epochs,j,len(train_loader),
                                                                loss.detach().cpu().item(), scheduler.get_last_lr()[0]))
    ckpt={"model":model.state_dict(),
            "model_ema":model_ema.state_dict()}
# Out:
# Epoch[1/50],Step[0/469],loss:1.14664,lr:0.00004
# Epoch[1/50],Step[10/469],loss:1.12188,lr:0.00004
# Epoch[1/50],Step[20/469],loss:1.09842,lr:0.00004
# Epoch[1/50],Step[30/469],loss:1.05951,lr:0.00004
# Epoch[1/50],Step[40/469],loss:1.04052,lr:0.00004
# Epoch[1/50],Step[50/469],loss:1.02767,lr:0.00004
# Epoch[1/50],Step[60/469],loss:1.01118,lr:0.00004
# Epoch[1/50],Step[70/469],loss:0.98567,lr:0.00004
# Epoch[1/50],Step[80/469],loss:0.96406,lr:0.00004
# Epoch[1/50],Step[90/469],loss:0.96012,lr:0.00004
# Epoch[1/50],Step[100/469],loss:0.93814,lr:0.00004
# Epoch[1/50],Step[110/469],loss:0.91206,lr:0.00004
# Epoch[1/50],Step[120/469],loss:0.89848,lr:0.00004
# Epoch[1/50],Step[130/469],loss:0.88099,lr:0.00004
# Epoch[1/50],Step[140/469],loss:0.86050,lr:0.00004
# Epoch[1/50],Step[150/469],loss:0.85684,lr:0.00004
# Epoch[1/50],Step[160/469],loss:0.83110,lr:0.00004
# Epoch[1/50],Step[170/469],loss:0.81757,lr:0.00004
# Epoch[1/50],Step[180/469],loss:0.79030,lr:0.00004
# Epoch[1/50],Step[190/469],loss:0.76830,lr:0.00004
# Epoch[1/50],Step[200/469],loss:0.75699,lr:0.00004
# Epoch[1/50],Step[210/469],loss:0.74290,lr:0.00004
# Epoch[1/50],Step[220/469],loss:0.72640,lr:0.00004
# Epoch[1/50],Step[230/469],loss:0.73071,lr:0.00004
# Epoch[1/50],Step[240/469],loss:0.69873,lr:0.00004
# Epoch[1/50],Step[250/469],loss:0.68295,lr:0.00004
# Epoch[1/50],Step[260/469],loss:0.65445,lr:0.00004
# Epoch[1/50],Step[270/469],loss:0.67081,lr:0.00005
# Epoch[1/50],Step[280/469],loss:0.62381,lr:0.00005
# Epoch[1/50],Step[290/469],loss:0.62590,lr:0.00005
# Epoch[1/50],Step[300/469],loss:0.62795,lr:0.00005
# Epoch[1/50],Step[310/469],loss:0.59384,lr:0.00005
# Epoch[1/50],Step[320/469],loss:0.58351,lr:0.00005
# Epoch[1/50],Step[330/469],loss:0.56100,lr:0.00005
# Epoch[1/50],Step[340/469],loss:0.54599,lr:0.00005
# Epoch[1/50],Step[350/469],loss:0.55719,lr:0.00005
# Epoch[1/50],Step[360/469],loss:0.54123,lr:0.00005
# Epoch[1/50],Step[370/469],loss:0.52917,lr:0.00005
# Epoch[1/50],Step[380/469],loss:0.54017,lr:0.00005
# Epoch[1/50],Step[390/469],loss:0.51187,lr:0.00005
# Epoch[1/50],Step[400/469],loss:0.48265,lr:0.00005
# Epoch[1/50],Step[410/469],loss:0.46479,lr:0.00005
# Epoch[1/50],Step[420/469],loss:0.47750,lr:0.00005
# Epoch[1/50],Step[430/469],loss:0.46447,lr:0.00005
# Epoch[1/50],Step[440/469],loss:0.47416,lr:0.00005
# Epoch[1/50],Step[450/469],loss:0.45606,lr:0.00005
# Epoch[1/50],Step[460/469],loss:0.45389,lr:0.00005
# Epoch[2/50],Step[0/469],loss:0.44816,lr:0.00006
# Epoch[2/50],Step[10/469],loss:0.42022,lr:0.00006
# Epoch[2/50],Step[20/469],loss:0.42574,lr:0.00006
# Epoch[2/50],Step[30/469],loss:0.42792,lr:0.00006
# Epoch[2/50],Step[40/469],loss:0.39508,lr:0.00006
# Epoch[2/50],Step[50/469],loss:0.40240,lr:0.00006
# Epoch[2/50],Step[60/469],loss:0.36919,lr:0.00006
# Epoch[2/50],Step[70/469],loss:0.39432,lr:0.00006
# Epoch[2/50],Step[80/469],loss:0.37670,lr:0.00006
# Epoch[2/50],Step[90/469],loss:0.36901,lr:0.00006
# Epoch[2/50],Step[100/469],loss:0.34690,lr:0.00006
# Epoch[2/50],Step[110/469],loss:0.34556,lr:0.00006
# Epoch[2/50],Step[120/469],loss:0.34234,lr:0.00006
# Epoch[2/50],Step[130/469],loss:0.35955,lr:0.00006
# Epoch[2/50],Step[140/469],loss:0.33061,lr:0.00007
# Epoch[2/50],Step[150/469],loss:0.32955,lr:0.00007
# Epoch[2/50],Step[160/469],loss:0.32667,lr:0.00007
# Epoch[2/50],Step[170/469],loss:0.34377,lr:0.00007
# Epoch[2/50],Step[180/469],loss:0.33371,lr:0.00007
# Epoch[2/50],Step[190/469],loss:0.32375,lr:0.00007
# Epoch[2/50],Step[200/469],loss:0.31229,lr:0.00007
# Epoch[2/50],Step[210/469],loss:0.29712,lr:0.00007
# Epoch[2/50],Step[220/469],loss:0.28840,lr:0.00007
# Epoch[2/50],Step[230/469],loss:0.29049,lr:0.00007
# Epoch[2/50],Step[240/469],loss:0.28389,lr:0.00007
# Epoch[2/50],Step[250/469],loss:0.27527,lr:0.00008
# Epoch[2/50],Step[260/469],loss:0.26998,lr:0.00008
# Epoch[2/50],Step[270/469],loss:0.29169,lr:0.00008
# Epoch[2/50],Step[280/469],loss:0.27422,lr:0.00008
# Epoch[2/50],Step[290/469],loss:0.27444,lr:0.00008
# Epoch[2/50],Step[300/469],loss:0.27083,lr:0.00008
# Epoch[2/50],Step[310/469],loss:0.25930,lr:0.00008
# Epoch[2/50],Step[320/469],loss:0.25632,lr:0.00008
# Epoch[2/50],Step[330/469],loss:0.24139,lr:0.00008
# Epoch[2/50],Step[340/469],loss:0.23867,lr:0.00008
# Epoch[2/50],Step[350/469],loss:0.24347,lr:0.00009
# Epoch[2/50],Step[360/469],loss:0.24758,lr:0.00009
# Epoch[2/50],Step[370/469],loss:0.24681,lr:0.00009
# Epoch[2/50],Step[380/469],loss:0.22385,lr:0.00009
# Epoch[2/50],Step[390/469],loss:0.23357,lr:0.00009
# Epoch[2/50],Step[400/469],loss:0.22226,lr:0.00009
# Epoch[2/50],Step[410/469],loss:0.21657,lr:0.00009
# Epoch[2/50],Step[420/469],loss:0.20711,lr:0.00009
# Epoch[2/50],Step[430/469],loss:0.20554,lr:0.00009
# Epoch[2/50],Step[440/469],loss:0.21613,lr:0.00010
# Epoch[2/50],Step[450/469],loss:0.22338,lr:0.00010
# Epoch[2/50],Step[460/469],loss:0.20876,lr:0.00010
# Epoch[3/50],Step[0/469],loss:0.20842,lr:0.00010
# Epoch[3/50],Step[10/469],loss:0.20567,lr:0.00010
# Epoch[3/50],Step[20/469],loss:0.18863,lr:0.00010
# Epoch[3/50],Step[30/469],loss:0.19414,lr:0.00010
# Epoch[3/50],Step[40/469],loss:0.19368,lr:0.00010
# Epoch[3/50],Step[50/469],loss:0.19086,lr:0.00011
# Epoch[3/50],Step[60/469],loss:0.18746,lr:0.00011
# Epoch[3/50],Step[70/469],loss:0.17862,lr:0.00011
# Epoch[3/50],Step[80/469],loss:0.17168,lr:0.00011
# Epoch[3/50],Step[90/469],loss:0.20479,lr:0.00011
# Epoch[3/50],Step[100/469],loss:0.15626,lr:0.00011
# Epoch[3/50],Step[110/469],loss:0.17070,lr:0.00011
# Epoch[3/50],Step[120/469],loss:0.18122,lr:0.00012
# Epoch[3/50],Step[130/469],loss:0.17140,lr:0.00012
# Epoch[3/50],Step[140/469],loss:0.16549,lr:0.00012
# Epoch[3/50],Step[150/469],loss:0.18011,lr:0.00012
# Epoch[3/50],Step[160/469],loss:0.15847,lr:0.00012
# Epoch[3/50],Step[170/469],loss:0.15913,lr:0.00012
# Epoch[3/50],Step[180/469],loss:0.18142,lr:0.00012
# Epoch[3/50],Step[190/469],loss:0.17332,lr:0.00013
# Epoch[3/50],Step[200/469],loss:0.14779,lr:0.00013
# Epoch[3/50],Step[210/469],loss:0.16782,lr:0.00013
# Epoch[3/50],Step[220/469],loss:0.14759,lr:0.00013
# Epoch[3/50],Step[230/469],loss:0.14343,lr:0.00013
# Epoch[3/50],Step[240/469],loss:0.13575,lr:0.00013
# Epoch[3/50],Step[250/469],loss:0.15326,lr:0.00013
# Epoch[3/50],Step[260/469],loss:0.14555,lr:0.00014
# Epoch[3/50],Step[270/469],loss:0.15408,lr:0.00014
# Epoch[3/50],Step[280/469],loss:0.13716,lr:0.00014
# Epoch[3/50],Step[290/469],loss:0.12683,lr:0.00014
# Epoch[3/50],Step[300/469],loss:0.13935,lr:0.00014
# Epoch[3/50],Step[310/469],loss:0.14668,lr:0.00014
# Epoch[3/50],Step[320/469],loss:0.13277,lr:0.00015
# Epoch[3/50],Step[330/469],loss:0.12912,lr:0.00015
# Epoch[3/50],Step[340/469],loss:0.14081,lr:0.00015
# Epoch[3/50],Step[350/469],loss:0.12420,lr:0.00015
# Epoch[3/50],Step[360/469],loss:0.13028,lr:0.00015
# Epoch[3/50],Step[370/469],loss:0.12825,lr:0.00015
# Epoch[3/50],Step[380/469],loss:0.11674,lr:0.00016
# Epoch[3/50],Step[390/469],loss:0.12322,lr:0.00016
# Epoch[3/50],Step[400/469],loss:0.12368,lr:0.00016
# Epoch[3/50],Step[410/469],loss:0.11634,lr:0.00016
# Epoch[3/50],Step[420/469],loss:0.11846,lr:0.00016
# Epoch[3/50],Step[430/469],loss:0.11714,lr:0.00016
# Epoch[3/50],Step[440/469],loss:0.11200,lr:0.00017
# Epoch[3/50],Step[450/469],loss:0.11404,lr:0.00017
# Epoch[3/50],Step[460/469],loss:0.12098,lr:0.00017
# Epoch[4/50],Step[0/469],loss:0.11339,lr:0.00017
# Epoch[4/50],Step[10/469],loss:0.10960,lr:0.00017
# Epoch[4/50],Step[20/469],loss:0.10797,lr:0.00017
# Epoch[4/50],Step[30/469],loss:0.11838,lr:0.00018
# Epoch[4/50],Step[40/469],loss:0.10326,lr:0.00018
# Epoch[4/50],Step[50/469],loss:0.09812,lr:0.00018
# Epoch[4/50],Step[60/469],loss:0.10266,lr:0.00018
# Epoch[4/50],Step[70/469],loss:0.10898,lr:0.00018
# Epoch[4/50],Step[80/469],loss:0.11031,lr:0.00018
# Epoch[4/50],Step[90/469],loss:0.10578,lr:0.00019
# Epoch[4/50],Step[100/469],loss:0.10133,lr:0.00019
# Epoch[4/50],Step[110/469],loss:0.11098,lr:0.00019
# Epoch[4/50],Step[120/469],loss:0.09831,lr:0.00019
# Epoch[4/50],Step[130/469],loss:0.09421,lr:0.00019
# Epoch[4/50],Step[140/469],loss:0.10479,lr:0.00020
# Epoch[4/50],Step[150/469],loss:0.10869,lr:0.00020
# Epoch[4/50],Step[160/469],loss:0.09184,lr:0.00020
# Epoch[4/50],Step[170/469],loss:0.09669,lr:0.00020
# Epoch[4/50],Step[180/469],loss:0.10039,lr:0.00020
# Epoch[4/50],Step[190/469],loss:0.08687,lr:0.00021
# Epoch[4/50],Step[200/469],loss:0.08953,lr:0.00021
# Epoch[4/50],Step[210/469],loss:0.09575,lr:0.00021
# Epoch[4/50],Step[220/469],loss:0.08596,lr:0.00021
# Epoch[4/50],Step[230/469],loss:0.10221,lr:0.00021
# Epoch[4/50],Step[240/469],loss:0.09332,lr:0.00022
# Epoch[4/50],Step[250/469],loss:0.08675,lr:0.00022
# Epoch[4/50],Step[260/469],loss:0.09146,lr:0.00022
# Epoch[4/50],Step[270/469],loss:0.09091,lr:0.00022
# Epoch[4/50],Step[280/469],loss:0.08224,lr:0.00022
# Epoch[4/50],Step[290/469],loss:0.09735,lr:0.00023
# Epoch[4/50],Step[300/469],loss:0.08184,lr:0.00023
# Epoch[4/50],Step[310/469],loss:0.08480,lr:0.00023
# Epoch[4/50],Step[320/469],loss:0.07565,lr:0.00023
# Epoch[4/50],Step[330/469],loss:0.08428,lr:0.00023
# Epoch[4/50],Step[340/469],loss:0.07421,lr:0.00024
# Epoch[4/50],Step[350/469],loss:0.08432,lr:0.00024
# Epoch[4/50],Step[360/469],loss:0.07698,lr:0.00024
# Epoch[4/50],Step[370/469],loss:0.08770,lr:0.00024
# Epoch[4/50],Step[380/469],loss:0.08182,lr:0.00024
# Epoch[4/50],Step[390/469],loss:0.08497,lr:0.00025
# Epoch[4/50],Step[400/469],loss:0.07943,lr:0.00025
# Epoch[4/50],Step[410/469],loss:0.07700,lr:0.00025
# Epoch[4/50],Step[420/469],loss:0.07752,lr:0.00025
# Epoch[4/50],Step[430/469],loss:0.09031,lr:0.00025
# Epoch[4/50],Step[440/469],loss:0.07741,lr:0.00026
# Epoch[4/50],Step[450/469],loss:0.07194,lr:0.00026
# Epoch[4/50],Step[460/469],loss:0.07039,lr:0.00026
# Epoch[5/50],Step[0/469],loss:0.08044,lr:0.00026
# Epoch[5/50],Step[10/469],loss:0.08462,lr:0.00027
# Epoch[5/50],Step[20/469],loss:0.07288,lr:0.00027
# Epoch[5/50],Step[30/469],loss:0.07524,lr:0.00027
# Epoch[5/50],Step[40/469],loss:0.06479,lr:0.00027
# Epoch[5/50],Step[50/469],loss:0.08169,lr:0.00027
# Epoch[5/50],Step[60/469],loss:0.07005,lr:0.00028
# Epoch[5/50],Step[70/469],loss:0.06759,lr:0.00028
# Epoch[5/50],Step[80/469],loss:0.07054,lr:0.00028
# Epoch[5/50],Step[90/469],loss:0.06824,lr:0.00028
# Epoch[5/50],Step[100/469],loss:0.07018,lr:0.00029
# Epoch[5/50],Step[110/469],loss:0.06676,lr:0.00029
# Epoch[5/50],Step[120/469],loss:0.06850,lr:0.00029
# Epoch[5/50],Step[130/469],loss:0.06645,lr:0.00029
# Epoch[5/50],Step[140/469],loss:0.06750,lr:0.00029
# Epoch[5/50],Step[150/469],loss:0.07144,lr:0.00030
# Epoch[5/50],Step[160/469],loss:0.06738,lr:0.00030
# Epoch[5/50],Step[170/469],loss:0.06402,lr:0.00030
# Epoch[5/50],Step[180/469],loss:0.06918,lr:0.00030
# Epoch[5/50],Step[190/469],loss:0.06834,lr:0.00031
# Epoch[5/50],Step[200/469],loss:0.06538,lr:0.00031
# Epoch[5/50],Step[210/469],loss:0.06226,lr:0.00031
# Epoch[5/50],Step[220/469],loss:0.06988,lr:0.00031
# Epoch[5/50],Step[230/469],loss:0.06852,lr:0.00031
# Epoch[5/50],Step[240/469],loss:0.06624,lr:0.00032
# Epoch[5/50],Step[250/469],loss:0.06742,lr:0.00032
# Epoch[5/50],Step[260/469],loss:0.06989,lr:0.00032
# Epoch[5/50],Step[270/469],loss:0.06341,lr:0.00032
# Epoch[5/50],Step[280/469],loss:0.06359,lr:0.00033
# Epoch[5/50],Step[290/469],loss:0.06404,lr:0.00033
# Epoch[5/50],Step[300/469],loss:0.06462,lr:0.00033
# Epoch[5/50],Step[310/469],loss:0.06176,lr:0.00033
# Epoch[5/50],Step[320/469],loss:0.05828,lr:0.00034
# Epoch[5/50],Step[330/469],loss:0.06057,lr:0.00034
# Epoch[5/50],Step[340/469],loss:0.06440,lr:0.00034
# Epoch[5/50],Step[350/469],loss:0.07500,lr:0.00034
# Epoch[5/50],Step[360/469],loss:0.06175,lr:0.00035
# Epoch[5/50],Step[370/469],loss:0.06025,lr:0.00035
# Epoch[5/50],Step[380/469],loss:0.06532,lr:0.00035
# Epoch[5/50],Step[390/469],loss:0.06007,lr:0.00035
# Epoch[5/50],Step[400/469],loss:0.05474,lr:0.00036
# Epoch[5/50],Step[410/469],loss:0.05406,lr:0.00036
# Epoch[5/50],Step[420/469],loss:0.05939,lr:0.00036
# Epoch[5/50],Step[430/469],loss:0.05640,lr:0.00036
# Epoch[5/50],Step[440/469],loss:0.08112,lr:0.00036
# Epoch[5/50],Step[450/469],loss:0.05633,lr:0.00037
# Epoch[5/50],Step[460/469],loss:0.07041,lr:0.00037
# Epoch[6/50],Step[0/469],loss:0.05457,lr:0.00037
# Epoch[6/50],Step[10/469],loss:0.06021,lr:0.00037
# Epoch[6/50],Step[20/469],loss:0.05745,lr:0.00038
# Epoch[6/50],Step[30/469],loss:0.05949,lr:0.00038
# Epoch[6/50],Step[40/469],loss:0.06387,lr:0.00038
# Epoch[6/50],Step[50/469],loss:0.06585,lr:0.00038
# Epoch[6/50],Step[60/469],loss:0.06640,lr:0.00039
# Epoch[6/50],Step[70/469],loss:0.05433,lr:0.00039
# Epoch[6/50],Step[80/469],loss:0.06938,lr:0.00039
# Epoch[6/50],Step[90/469],loss:0.05355,lr:0.00039
# Epoch[6/50],Step[100/469],loss:0.05557,lr:0.00040
# Epoch[6/50],Step[110/469],loss:0.06882,lr:0.00040
# Epoch[6/50],Step[120/469],loss:0.06098,lr:0.00040
# Epoch[6/50],Step[130/469],loss:0.05226,lr:0.00040
# Epoch[6/50],Step[140/469],loss:0.05491,lr:0.00041
# Epoch[6/50],Step[150/469],loss:0.05283,lr:0.00041
# Epoch[6/50],Step[160/469],loss:0.05282,lr:0.00041
# Epoch[6/50],Step[170/469],loss:0.05444,lr:0.00041
# Epoch[6/50],Step[180/469],loss:0.05175,lr:0.00042
# Epoch[6/50],Step[190/469],loss:0.06058,lr:0.00042
# Epoch[6/50],Step[200/469],loss:0.05027,lr:0.00042
# Epoch[6/50],Step[210/469],loss:0.05914,lr:0.00042
# Epoch[6/50],Step[220/469],loss:0.05847,lr:0.00043
# Epoch[6/50],Step[230/469],loss:0.05685,lr:0.00043
# Epoch[6/50],Step[240/469],loss:0.05151,lr:0.00043
# Epoch[6/50],Step[250/469],loss:0.06315,lr:0.00043
# Epoch[6/50],Step[260/469],loss:0.05593,lr:0.00044
# Epoch[6/50],Step[270/469],loss:0.05433,lr:0.00044
# Epoch[6/50],Step[280/469],loss:0.06207,lr:0.00044
# Epoch[6/50],Step[290/469],loss:0.05217,lr:0.00044
# Epoch[6/50],Step[300/469],loss:0.05576,lr:0.00045
# Epoch[6/50],Step[310/469],loss:0.06455,lr:0.00045
# Epoch[6/50],Step[320/469],loss:0.06025,lr:0.00045
# Epoch[6/50],Step[330/469],loss:0.05057,lr:0.00045
# Epoch[6/50],Step[340/469],loss:0.05393,lr:0.00046
# Epoch[6/50],Step[350/469],loss:0.04677,lr:0.00046
# Epoch[6/50],Step[360/469],loss:0.06578,lr:0.00046
# Epoch[6/50],Step[370/469],loss:0.05953,lr:0.00046
# Epoch[6/50],Step[380/469],loss:0.05331,lr:0.00047
# Epoch[6/50],Step[390/469],loss:0.05022,lr:0.00047
# Epoch[6/50],Step[400/469],loss:0.05812,lr:0.00047
# Epoch[6/50],Step[410/469],loss:0.05443,lr:0.00048
# Epoch[6/50],Step[420/469],loss:0.04553,lr:0.00048
# Epoch[6/50],Step[430/469],loss:0.05095,lr:0.00048
# Epoch[6/50],Step[440/469],loss:0.05407,lr:0.00048
# Epoch[6/50],Step[450/469],loss:0.05053,lr:0.00049
# Epoch[6/50],Step[460/469],loss:0.04451,lr:0.00049
# Epoch[7/50],Step[0/469],loss:0.04980,lr:0.00049
# Epoch[7/50],Step[10/469],loss:0.05190,lr:0.00049
# Epoch[7/50],Step[20/469],loss:0.05218,lr:0.00050
# Epoch[7/50],Step[30/469],loss:0.05344,lr:0.00050
# Epoch[7/50],Step[40/469],loss:0.05872,lr:0.00050
# Epoch[7/50],Step[50/469],loss:0.04523,lr:0.00050
# Epoch[7/50],Step[60/469],loss:0.04627,lr:0.00051
# Epoch[7/50],Step[70/469],loss:0.05564,lr:0.00051
# Epoch[7/50],Step[80/469],loss:0.04323,lr:0.00051
# Epoch[7/50],Step[90/469],loss:0.04770,lr:0.00051
# Epoch[7/50],Step[100/469],loss:0.05732,lr:0.00052
# Epoch[7/50],Step[110/469],loss:0.05079,lr:0.00052
# Epoch[7/50],Step[120/469],loss:0.05022,lr:0.00052
# Epoch[7/50],Step[130/469],loss:0.05493,lr:0.00052
# Epoch[7/50],Step[140/469],loss:0.04698,lr:0.00053
# Epoch[7/50],Step[150/469],loss:0.04752,lr:0.00053
# Epoch[7/50],Step[160/469],loss:0.05015,lr:0.00053
# Epoch[7/50],Step[170/469],loss:0.04463,lr:0.00053
# Epoch[7/50],Step[180/469],loss:0.04778,lr:0.00054
# Epoch[7/50],Step[190/469],loss:0.04600,lr:0.00054
# Epoch[7/50],Step[200/469],loss:0.05437,lr:0.00054
# Epoch[7/50],Step[210/469],loss:0.05598,lr:0.00054
# Epoch[7/50],Step[220/469],loss:0.04280,lr:0.00055
# Epoch[7/50],Step[230/469],loss:0.04713,lr:0.00055
# Epoch[7/50],Step[240/469],loss:0.04154,lr:0.00055
# Epoch[7/50],Step[250/469],loss:0.04648,lr:0.00055
# Epoch[7/50],Step[260/469],loss:0.04723,lr:0.00056
# Epoch[7/50],Step[270/469],loss:0.05294,lr:0.00056
# Epoch[7/50],Step[280/469],loss:0.04244,lr:0.00056
# Epoch[7/50],Step[290/469],loss:0.04163,lr:0.00056
# Epoch[7/50],Step[300/469],loss:0.05565,lr:0.00057
# Epoch[7/50],Step[310/469],loss:0.04544,lr:0.00057
# Epoch[7/50],Step[320/469],loss:0.05027,lr:0.00057
# Epoch[7/50],Step[330/469],loss:0.04031,lr:0.00057
# Epoch[7/50],Step[340/469],loss:0.05286,lr:0.00058
# Epoch[7/50],Step[350/469],loss:0.04874,lr:0.00058
# Epoch[7/50],Step[360/469],loss:0.05758,lr:0.00058
# Epoch[7/50],Step[370/469],loss:0.05398,lr:0.00059
# Epoch[7/50],Step[380/469],loss:0.04686,lr:0.00059
# Epoch[7/50],Step[390/469],loss:0.05023,lr:0.00059
# Epoch[7/50],Step[400/469],loss:0.04978,lr:0.00059
# Epoch[7/50],Step[410/469],loss:0.04494,lr:0.00060
# Epoch[7/50],Step[420/469],loss:0.05464,lr:0.00060
# Epoch[7/50],Step[430/469],loss:0.04502,lr:0.00060
# Epoch[7/50],Step[440/469],loss:0.04017,lr:0.00060
# Epoch[7/50],Step[450/469],loss:0.03823,lr:0.00061
# Epoch[7/50],Step[460/469],loss:0.04847,lr:0.00061
# Epoch[8/50],Step[0/469],loss:0.04514,lr:0.00061
# Epoch[8/50],Step[10/469],loss:0.05247,lr:0.00061
# Epoch[8/50],Step[20/469],loss:0.05499,lr:0.00062
# Epoch[8/50],Step[30/469],loss:0.04432,lr:0.00062
# Epoch[8/50],Step[40/469],loss:0.04535,lr:0.00062
# Epoch[8/50],Step[50/469],loss:0.04435,lr:0.00062
# Epoch[8/50],Step[60/469],loss:0.04624,lr:0.00063
# Epoch[8/50],Step[70/469],loss:0.05155,lr:0.00063
# Epoch[8/50],Step[80/469],loss:0.04546,lr:0.00063
# Epoch[8/50],Step[90/469],loss:0.04677,lr:0.00063
# Epoch[8/50],Step[100/469],loss:0.04846,lr:0.00064
# Epoch[8/50],Step[110/469],loss:0.04115,lr:0.00064
# Epoch[8/50],Step[120/469],loss:0.03840,lr:0.00064
# Epoch[8/50],Step[130/469],loss:0.05039,lr:0.00064
# Epoch[8/50],Step[140/469],loss:0.05243,lr:0.00065
# Epoch[8/50],Step[150/469],loss:0.04721,lr:0.00065
# Epoch[8/50],Step[160/469],loss:0.04805,lr:0.00065
# Epoch[8/50],Step[170/469],loss:0.03933,lr:0.00065
# Epoch[8/50],Step[180/469],loss:0.04496,lr:0.00066
# Epoch[8/50],Step[190/469],loss:0.04117,lr:0.00066
# Epoch[8/50],Step[200/469],loss:0.04311,lr:0.00066
# Epoch[8/50],Step[210/469],loss:0.04980,lr:0.00066
# Epoch[8/50],Step[220/469],loss:0.04762,lr:0.00067
# Epoch[8/50],Step[230/469],loss:0.04249,lr:0.00067
# Epoch[8/50],Step[240/469],loss:0.04893,lr:0.00067
# Epoch[8/50],Step[250/469],loss:0.04110,lr:0.00067
# Epoch[8/50],Step[260/469],loss:0.04100,lr:0.00067
# Epoch[8/50],Step[270/469],loss:0.04481,lr:0.00068
# Epoch[8/50],Step[280/469],loss:0.04735,lr:0.00068
# Epoch[8/50],Step[290/469],loss:0.03805,lr:0.00068
# Epoch[8/50],Step[300/469],loss:0.04720,lr:0.00068
# Epoch[8/50],Step[310/469],loss:0.03673,lr:0.00069
# Epoch[8/50],Step[320/469],loss:0.03803,lr:0.00069
# Epoch[8/50],Step[330/469],loss:0.04192,lr:0.00069
# Epoch[8/50],Step[340/469],loss:0.04287,lr:0.00069
# Epoch[8/50],Step[350/469],loss:0.04684,lr:0.00070
# Epoch[8/50],Step[360/469],loss:0.04298,lr:0.00070
# Epoch[8/50],Step[370/469],loss:0.04636,lr:0.00070
# Epoch[8/50],Step[380/469],loss:0.04322,lr:0.00070
# Epoch[8/50],Step[390/469],loss:0.04242,lr:0.00071
# Epoch[8/50],Step[400/469],loss:0.04289,lr:0.00071
# Epoch[8/50],Step[410/469],loss:0.05324,lr:0.00071
# Epoch[8/50],Step[420/469],loss:0.04208,lr:0.00071
# Epoch[8/50],Step[430/469],loss:0.04056,lr:0.00072
# Epoch[8/50],Step[440/469],loss:0.03836,lr:0.00072
# Epoch[8/50],Step[450/469],loss:0.04077,lr:0.00072
# Epoch[8/50],Step[460/469],loss:0.05025,lr:0.00072
# Epoch[9/50],Step[0/469],loss:0.04115,lr:0.00072
# Epoch[9/50],Step[10/469],loss:0.03698,lr:0.00073
# Epoch[9/50],Step[20/469],loss:0.04117,lr:0.00073
# Epoch[9/50],Step[30/469],loss:0.03504,lr:0.00073
# Epoch[9/50],Step[40/469],loss:0.04952,lr:0.00073
# Epoch[9/50],Step[50/469],loss:0.03869,lr:0.00074
# Epoch[9/50],Step[60/469],loss:0.03675,lr:0.00074
# Epoch[9/50],Step[70/469],loss:0.04179,lr:0.00074
# Epoch[9/50],Step[80/469],loss:0.04768,lr:0.00074
# Epoch[9/50],Step[90/469],loss:0.04165,lr:0.00075
# Epoch[9/50],Step[100/469],loss:0.04015,lr:0.00075
# Epoch[9/50],Step[110/469],loss:0.04223,lr:0.00075
# Epoch[9/50],Step[120/469],loss:0.04957,lr:0.00075
# Epoch[9/50],Step[130/469],loss:0.04478,lr:0.00075
# Epoch[9/50],Step[140/469],loss:0.04951,lr:0.00076
# Epoch[9/50],Step[150/469],loss:0.04375,lr:0.00076
# Epoch[9/50],Step[160/469],loss:0.03839,lr:0.00076
# Epoch[9/50],Step[170/469],loss:0.03900,lr:0.00076
# Epoch[9/50],Step[180/469],loss:0.03779,lr:0.00077
# Epoch[9/50],Step[190/469],loss:0.04188,lr:0.00077
# Epoch[9/50],Step[200/469],loss:0.03820,lr:0.00077
# Epoch[9/50],Step[210/469],loss:0.05165,lr:0.00077
# Epoch[9/50],Step[220/469],loss:0.04191,lr:0.00077
# Epoch[9/50],Step[230/469],loss:0.04546,lr:0.00078
# Epoch[9/50],Step[240/469],loss:0.04363,lr:0.00078
# Epoch[9/50],Step[250/469],loss:0.03887,lr:0.00078
# Epoch[9/50],Step[260/469],loss:0.05204,lr:0.00078
# Epoch[9/50],Step[270/469],loss:0.03668,lr:0.00079
# Epoch[9/50],Step[280/469],loss:0.03950,lr:0.00079
# Epoch[9/50],Step[290/469],loss:0.03821,lr:0.00079
# Epoch[9/50],Step[300/469],loss:0.03739,lr:0.00079
# Epoch[9/50],Step[310/469],loss:0.04265,lr:0.00079
# Epoch[9/50],Step[320/469],loss:0.03569,lr:0.00080
# Epoch[9/50],Step[330/469],loss:0.03883,lr:0.00080
# Epoch[9/50],Step[340/469],loss:0.03857,lr:0.00080
# Epoch[9/50],Step[350/469],loss:0.03654,lr:0.00080
# Epoch[9/50],Step[360/469],loss:0.03675,lr:0.00080
# Epoch[9/50],Step[370/469],loss:0.03762,lr:0.00081
# Epoch[9/50],Step[380/469],loss:0.03864,lr:0.00081
# Epoch[9/50],Step[390/469],loss:0.03983,lr:0.00081
# Epoch[9/50],Step[400/469],loss:0.04227,lr:0.00081
# Epoch[9/50],Step[410/469],loss:0.03931,lr:0.00081
# Epoch[9/50],Step[420/469],loss:0.03644,lr:0.00082
# Epoch[9/50],Step[430/469],loss:0.05059,lr:0.00082
# Epoch[9/50],Step[440/469],loss:0.03355,lr:0.00082
# Epoch[9/50],Step[450/469],loss:0.03453,lr:0.00082
# Epoch[9/50],Step[460/469],loss:0.03735,lr:0.00082
# Epoch[10/50],Step[0/469],loss:0.03574,lr:0.00083
# Epoch[10/50],Step[10/469],loss:0.04074,lr:0.00083
# Epoch[10/50],Step[20/469],loss:0.03631,lr:0.00083
# Epoch[10/50],Step[30/469],loss:0.03804,lr:0.00083
# Epoch[10/50],Step[40/469],loss:0.04421,lr:0.00083
# Epoch[10/50],Step[50/469],loss:0.03879,lr:0.00084
# Epoch[10/50],Step[60/469],loss:0.04106,lr:0.00084
# Epoch[10/50],Step[70/469],loss:0.03536,lr:0.00084
# Epoch[10/50],Step[80/469],loss:0.03854,lr:0.00084
# Epoch[10/50],Step[90/469],loss:0.04537,lr:0.00084
# Epoch[10/50],Step[100/469],loss:0.03697,lr:0.00085
# Epoch[10/50],Step[110/469],loss:0.04880,lr:0.00085
# Epoch[10/50],Step[120/469],loss:0.03534,lr:0.00085
# Epoch[10/50],Step[130/469],loss:0.03589,lr:0.00085
# Epoch[10/50],Step[140/469],loss:0.03576,lr:0.00085
# Epoch[10/50],Step[150/469],loss:0.03562,lr:0.00085
# Epoch[10/50],Step[160/469],loss:0.03553,lr:0.00086
# Epoch[10/50],Step[170/469],loss:0.03911,lr:0.00086
# Epoch[10/50],Step[180/469],loss:0.03767,lr:0.00086
# Epoch[10/50],Step[190/469],loss:0.03846,lr:0.00086
# Epoch[10/50],Step[200/469],loss:0.03906,lr:0.00086
# Epoch[10/50],Step[210/469],loss:0.03482,lr:0.00087
# Epoch[10/50],Step[220/469],loss:0.04107,lr:0.00087
# Epoch[10/50],Step[230/469],loss:0.03736,lr:0.00087
# Epoch[10/50],Step[240/469],loss:0.03635,lr:0.00087
# Epoch[10/50],Step[250/469],loss:0.04357,lr:0.00087
# Epoch[10/50],Step[260/469],loss:0.03486,lr:0.00087
# Epoch[10/50],Step[270/469],loss:0.03416,lr:0.00088
# Epoch[10/50],Step[280/469],loss:0.04668,lr:0.00088
# Epoch[10/50],Step[290/469],loss:0.03067,lr:0.00088
# Epoch[10/50],Step[300/469],loss:0.03898,lr:0.00088
# Epoch[10/50],Step[310/469],loss:0.03738,lr:0.00088
# Epoch[10/50],Step[320/469],loss:0.03874,lr:0.00088
# Epoch[10/50],Step[330/469],loss:0.04482,lr:0.00089
# Epoch[10/50],Step[340/469],loss:0.03757,lr:0.00089
# Epoch[10/50],Step[350/469],loss:0.03089,lr:0.00089
# Epoch[10/50],Step[360/469],loss:0.03656,lr:0.00089
# Epoch[10/50],Step[370/469],loss:0.03121,lr:0.00089
# Epoch[10/50],Step[380/469],loss:0.03822,lr:0.00089
# Epoch[10/50],Step[390/469],loss:0.03372,lr:0.00090
# Epoch[10/50],Step[400/469],loss:0.03637,lr:0.00090
# Epoch[10/50],Step[410/469],loss:0.03584,lr:0.00090
# Epoch[10/50],Step[420/469],loss:0.03566,lr:0.00090
# Epoch[10/50],Step[430/469],loss:0.03216,lr:0.00090
# Epoch[10/50],Step[440/469],loss:0.03524,lr:0.00090
# Epoch[10/50],Step[450/469],loss:0.04453,lr:0.00091
# Epoch[10/50],Step[460/469],loss:0.03457,lr:0.00091
# Epoch[11/50],Step[0/469],loss:0.03521,lr:0.00091
# Epoch[11/50],Step[10/469],loss:0.03272,lr:0.00091
# Epoch[11/50],Step[20/469],loss:0.03394,lr:0.00091
# Epoch[11/50],Step[30/469],loss:0.03362,lr:0.00091
# Epoch[11/50],Step[40/469],loss:0.03300,lr:0.00091
# Epoch[11/50],Step[50/469],loss:0.03191,lr:0.00092
# Epoch[11/50],Step[60/469],loss:0.03344,lr:0.00092
# Epoch[11/50],Step[70/469],loss:0.03356,lr:0.00092
# Epoch[11/50],Step[80/469],loss:0.03762,lr:0.00092
# Epoch[11/50],Step[90/469],loss:0.03478,lr:0.00092
# Epoch[11/50],Step[100/469],loss:0.03351,lr:0.00092
# Epoch[11/50],Step[110/469],loss:0.03439,lr:0.00092
# Epoch[11/50],Step[120/469],loss:0.03516,lr:0.00093
# Epoch[11/50],Step[130/469],loss:0.03651,lr:0.00093
# Epoch[11/50],Step[140/469],loss:0.03337,lr:0.00093
# Epoch[11/50],Step[150/469],loss:0.03735,lr:0.00093
# Epoch[11/50],Step[160/469],loss:0.04824,lr:0.00093
# Epoch[11/50],Step[170/469],loss:0.03827,lr:0.00093
# Epoch[11/50],Step[180/469],loss:0.03483,lr:0.00093
# Epoch[11/50],Step[190/469],loss:0.03624,lr:0.00094
# Epoch[11/50],Step[200/469],loss:0.02964,lr:0.00094
# Epoch[11/50],Step[210/469],loss:0.03795,lr:0.00094
# Epoch[11/50],Step[220/469],loss:0.03263,lr:0.00094
# Epoch[11/50],Step[230/469],loss:0.03566,lr:0.00094
# Epoch[11/50],Step[240/469],loss:0.03051,lr:0.00094
# Epoch[11/50],Step[250/469],loss:0.03308,lr:0.00094
# Epoch[11/50],Step[260/469],loss:0.03733,lr:0.00094
# Epoch[11/50],Step[270/469],loss:0.03306,lr:0.00095
# Epoch[11/50],Step[280/469],loss:0.04152,lr:0.00095
# Epoch[11/50],Step[290/469],loss:0.03360,lr:0.00095
# Epoch[11/50],Step[300/469],loss:0.03173,lr:0.00095
# Epoch[11/50],Step[310/469],loss:0.03332,lr:0.00095
# Epoch[11/50],Step[320/469],loss:0.03821,lr:0.00095
# Epoch[11/50],Step[330/469],loss:0.03145,lr:0.00095
# Epoch[11/50],Step[340/469],loss:0.03315,lr:0.00095
# Epoch[11/50],Step[350/469],loss:0.03212,lr:0.00095
# Epoch[11/50],Step[360/469],loss:0.03258,lr:0.00096
# Epoch[11/50],Step[370/469],loss:0.02984,lr:0.00096
# Epoch[11/50],Step[380/469],loss:0.03584,lr:0.00096
# Epoch[11/50],Step[390/469],loss:0.02995,lr:0.00096
# Epoch[11/50],Step[400/469],loss:0.04056,lr:0.00096
# Epoch[11/50],Step[410/469],loss:0.03481,lr:0.00096
# Epoch[11/50],Step[420/469],loss:0.03261,lr:0.00096
# Epoch[11/50],Step[430/469],loss:0.02953,lr:0.00096
# Epoch[11/50],Step[440/469],loss:0.02895,lr:0.00096
# Epoch[11/50],Step[450/469],loss:0.03592,lr:0.00096
# Epoch[11/50],Step[460/469],loss:0.03999,lr:0.00097
# Epoch[12/50],Step[0/469],loss:0.03034,lr:0.00097
# Epoch[12/50],Step[10/469],loss:0.04496,lr:0.00097
# Epoch[12/50],Step[20/469],loss:0.03643,lr:0.00097
# Epoch[12/50],Step[30/469],loss:0.02997,lr:0.00097
# Epoch[12/50],Step[40/469],loss:0.02875,lr:0.00097
# Epoch[12/50],Step[50/469],loss:0.04112,lr:0.00097
# Epoch[12/50],Step[60/469],loss:0.03122,lr:0.00097
# Epoch[12/50],Step[70/469],loss:0.02934,lr:0.00097
# Epoch[12/50],Step[80/469],loss:0.03341,lr:0.00097
# Epoch[12/50],Step[90/469],loss:0.03292,lr:0.00097
# Epoch[12/50],Step[100/469],loss:0.03021,lr:0.00098
# Epoch[12/50],Step[110/469],loss:0.02819,lr:0.00098
# Epoch[12/50],Step[120/469],loss:0.03446,lr:0.00098
# Epoch[12/50],Step[130/469],loss:0.03695,lr:0.00098
# Epoch[12/50],Step[140/469],loss:0.02828,lr:0.00098
# Epoch[12/50],Step[150/469],loss:0.02841,lr:0.00098
# Epoch[12/50],Step[160/469],loss:0.03207,lr:0.00098
# Epoch[12/50],Step[170/469],loss:0.03353,lr:0.00098
# Epoch[12/50],Step[180/469],loss:0.03865,lr:0.00098
# Epoch[12/50],Step[190/469],loss:0.03368,lr:0.00098
# Epoch[12/50],Step[200/469],loss:0.03192,lr:0.00098
# Epoch[12/50],Step[210/469],loss:0.03619,lr:0.00098
# Epoch[12/50],Step[220/469],loss:0.03498,lr:0.00098
# Epoch[12/50],Step[230/469],loss:0.02881,lr:0.00098
# Epoch[12/50],Step[240/469],loss:0.03130,lr:0.00099
# Epoch[12/50],Step[250/469],loss:0.03004,lr:0.00099
# Epoch[12/50],Step[260/469],loss:0.03725,lr:0.00099
# Epoch[12/50],Step[270/469],loss:0.03179,lr:0.00099
# Epoch[12/50],Step[280/469],loss:0.03113,lr:0.00099
# Epoch[12/50],Step[290/469],loss:0.02943,lr:0.00099
# Epoch[12/50],Step[300/469],loss:0.02978,lr:0.00099
# Epoch[12/50],Step[310/469],loss:0.03545,lr:0.00099
# Epoch[12/50],Step[320/469],loss:0.03152,lr:0.00099
# Epoch[12/50],Step[330/469],loss:0.03345,lr:0.00099
# Epoch[12/50],Step[340/469],loss:0.03529,lr:0.00099
# Epoch[12/50],Step[350/469],loss:0.03037,lr:0.00099
# Epoch[12/50],Step[360/469],loss:0.02719,lr:0.00099
# Epoch[12/50],Step[370/469],loss:0.03788,lr:0.00099
# Epoch[12/50],Step[380/469],loss:0.03080,lr:0.00099
# Epoch[12/50],Step[390/469],loss:0.03544,lr:0.00099
# Epoch[12/50],Step[400/469],loss:0.04035,lr:0.00099
# Epoch[12/50],Step[410/469],loss:0.02906,lr:0.00099
# Epoch[12/50],Step[420/469],loss:0.03370,lr:0.00099
# Epoch[12/50],Step[430/469],loss:0.02895,lr:0.00099
# Epoch[12/50],Step[440/469],loss:0.02866,lr:0.00100
# Epoch[12/50],Step[450/469],loss:0.03139,lr:0.00100
# Epoch[12/50],Step[460/469],loss:0.03183,lr:0.00100
# Epoch[13/50],Step[0/469],loss:0.03365,lr:0.00100
# Epoch[13/50],Step[10/469],loss:0.03632,lr:0.00100
# Epoch[13/50],Step[20/469],loss:0.03454,lr:0.00100
# Epoch[13/50],Step[30/469],loss:0.02919,lr:0.00100
# Epoch[13/50],Step[40/469],loss:0.03624,lr:0.00100
# Epoch[13/50],Step[50/469],loss:0.03222,lr:0.00100
# Epoch[13/50],Step[60/469],loss:0.03295,lr:0.00100
# Epoch[13/50],Step[70/469],loss:0.03004,lr:0.00100
# Epoch[13/50],Step[80/469],loss:0.02940,lr:0.00100
# Epoch[13/50],Step[90/469],loss:0.02597,lr:0.00100
# Epoch[13/50],Step[100/469],loss:0.03305,lr:0.00100
# Epoch[13/50],Step[110/469],loss:0.03113,lr:0.00100
# Epoch[13/50],Step[120/469],loss:0.03211,lr:0.00100
# Epoch[13/50],Step[130/469],loss:0.02827,lr:0.00100
# Epoch[13/50],Step[140/469],loss:0.02928,lr:0.00100
# Epoch[13/50],Step[150/469],loss:0.03337,lr:0.00100
# Epoch[13/50],Step[160/469],loss:0.03586,lr:0.00100
# Epoch[13/50],Step[170/469],loss:0.03800,lr:0.00100
# Epoch[13/50],Step[180/469],loss:0.03020,lr:0.00100
# Epoch[13/50],Step[190/469],loss:0.03340,lr:0.00100
# Epoch[13/50],Step[200/469],loss:0.02727,lr:0.00100
# Epoch[13/50],Step[210/469],loss:0.02993,lr:0.00100
# Epoch[13/50],Step[220/469],loss:0.03305,lr:0.00100
# Epoch[13/50],Step[230/469],loss:0.03007,lr:0.00100
# Epoch[13/50],Step[240/469],loss:0.02862,lr:0.00100
# Epoch[13/50],Step[250/469],loss:0.03112,lr:0.00100
# Epoch[13/50],Step[260/469],loss:0.03262,lr:0.00100
# Epoch[13/50],Step[270/469],loss:0.02988,lr:0.00100
# Epoch[13/50],Step[280/469],loss:0.02673,lr:0.00100
# Epoch[13/50],Step[290/469],loss:0.02824,lr:0.00100
# Epoch[13/50],Step[300/469],loss:0.03299,lr:0.00100
# Epoch[13/50],Step[310/469],loss:0.03940,lr:0.00100
# Epoch[13/50],Step[320/469],loss:0.03485,lr:0.00100
# Epoch[13/50],Step[330/469],loss:0.02950,lr:0.00100
# Epoch[13/50],Step[340/469],loss:0.02832,lr:0.00100
# Epoch[13/50],Step[350/469],loss:0.03120,lr:0.00100
# Epoch[13/50],Step[360/469],loss:0.03150,lr:0.00100
# Epoch[13/50],Step[370/469],loss:0.03545,lr:0.00100
# Epoch[13/50],Step[380/469],loss:0.03883,lr:0.00100
# Epoch[13/50],Step[390/469],loss:0.03219,lr:0.00100
# Epoch[13/50],Step[400/469],loss:0.03432,lr:0.00100
# Epoch[13/50],Step[410/469],loss:0.03679,lr:0.00100
# Epoch[13/50],Step[420/469],loss:0.03090,lr:0.00100
# Epoch[13/50],Step[430/469],loss:0.03356,lr:0.00100
# Epoch[13/50],Step[440/469],loss:0.02863,lr:0.00100
# Epoch[13/50],Step[450/469],loss:0.02867,lr:0.00100
# Epoch[13/50],Step[460/469],loss:0.03029,lr:0.00100
# Epoch[14/50],Step[0/469],loss:0.02907,lr:0.00100
# Epoch[14/50],Step[10/469],loss:0.02737,lr:0.00100
# Epoch[14/50],Step[20/469],loss:0.03389,lr:0.00100
# Epoch[14/50],Step[30/469],loss:0.03343,lr:0.00100
# Epoch[14/50],Step[40/469],loss:0.02818,lr:0.00100
# Epoch[14/50],Step[50/469],loss:0.02747,lr:0.00100
# Epoch[14/50],Step[60/469],loss:0.03023,lr:0.00100
# Epoch[14/50],Step[70/469],loss:0.03368,lr:0.00100
# Epoch[14/50],Step[80/469],loss:0.02490,lr:0.00100
# Epoch[14/50],Step[90/469],loss:0.03246,lr:0.00100
# Epoch[14/50],Step[100/469],loss:0.03043,lr:0.00100
# Epoch[14/50],Step[110/469],loss:0.03254,lr:0.00100
# Epoch[14/50],Step[120/469],loss:0.03091,lr:0.00100
# Epoch[14/50],Step[130/469],loss:0.03366,lr:0.00100
# Epoch[14/50],Step[140/469],loss:0.02849,lr:0.00100
# Epoch[14/50],Step[150/469],loss:0.03079,lr:0.00100
# Epoch[14/50],Step[160/469],loss:0.03008,lr:0.00100
# Epoch[14/50],Step[170/469],loss:0.03373,lr:0.00100
# Epoch[14/50],Step[180/469],loss:0.03064,lr:0.00100
# Epoch[14/50],Step[190/469],loss:0.03727,lr:0.00100
# Epoch[14/50],Step[200/469],loss:0.02908,lr:0.00100
# Epoch[14/50],Step[210/469],loss:0.03428,lr:0.00100
# Epoch[14/50],Step[220/469],loss:0.03418,lr:0.00100
# Epoch[14/50],Step[230/469],loss:0.02925,lr:0.00100
# Epoch[14/50],Step[240/469],loss:0.02849,lr:0.00100
# Epoch[14/50],Step[250/469],loss:0.03377,lr:0.00100
# Epoch[14/50],Step[260/469],loss:0.03135,lr:0.00100
# Epoch[14/50],Step[270/469],loss:0.02959,lr:0.00100
# Epoch[14/50],Step[280/469],loss:0.02747,lr:0.00100
# Epoch[14/50],Step[290/469],loss:0.03740,lr:0.00100
# Epoch[14/50],Step[300/469],loss:0.03875,lr:0.00100
# Epoch[14/50],Step[310/469],loss:0.02922,lr:0.00100
# Epoch[14/50],Step[320/469],loss:0.02922,lr:0.00100
# Epoch[14/50],Step[330/469],loss:0.02844,lr:0.00100
# Epoch[14/50],Step[340/469],loss:0.03768,lr:0.00100
# Epoch[14/50],Step[350/469],loss:0.03219,lr:0.00100
# Epoch[14/50],Step[360/469],loss:0.03125,lr:0.00100
# Epoch[14/50],Step[370/469],loss:0.02730,lr:0.00100
# Epoch[14/50],Step[380/469],loss:0.02679,lr:0.00100
# Epoch[14/50],Step[390/469],loss:0.02983,lr:0.00100
# Epoch[14/50],Step[400/469],loss:0.03251,lr:0.00100
# Epoch[14/50],Step[410/469],loss:0.03408,lr:0.00100
# Epoch[14/50],Step[420/469],loss:0.03029,lr:0.00100
# Epoch[14/50],Step[430/469],loss:0.03055,lr:0.00100
# Epoch[14/50],Step[440/469],loss:0.02709,lr:0.00100
# Epoch[14/50],Step[450/469],loss:0.02951,lr:0.00100
# Epoch[14/50],Step[460/469],loss:0.03326,lr:0.00100
# Epoch[15/50],Step[0/469],loss:0.03080,lr:0.00100
# Epoch[15/50],Step[10/469],loss:0.02919,lr:0.00100
# Epoch[15/50],Step[20/469],loss:0.02524,lr:0.00100
# Epoch[15/50],Step[30/469],loss:0.03162,lr:0.00100
# Epoch[15/50],Step[40/469],loss:0.03333,lr:0.00100
# Epoch[15/50],Step[50/469],loss:0.03190,lr:0.00100
# Epoch[15/50],Step[60/469],loss:0.02896,lr:0.00100
# Epoch[15/50],Step[70/469],loss:0.02613,lr:0.00100
# Epoch[15/50],Step[80/469],loss:0.03659,lr:0.00100
# Epoch[15/50],Step[90/469],loss:0.02898,lr:0.00099
# Epoch[15/50],Step[100/469],loss:0.03101,lr:0.00099
# Epoch[15/50],Step[110/469],loss:0.03387,lr:0.00099
# Epoch[15/50],Step[120/469],loss:0.02683,lr:0.00099
# Epoch[15/50],Step[130/469],loss:0.02734,lr:0.00099
# Epoch[15/50],Step[140/469],loss:0.03374,lr:0.00099
# Epoch[15/50],Step[150/469],loss:0.03334,lr:0.00099
# Epoch[15/50],Step[160/469],loss:0.04525,lr:0.00099
# Epoch[15/50],Step[170/469],loss:0.02637,lr:0.00099
# Epoch[15/50],Step[180/469],loss:0.02882,lr:0.00099
# Epoch[15/50],Step[190/469],loss:0.03227,lr:0.00099
# Epoch[15/50],Step[200/469],loss:0.03246,lr:0.00099
# Epoch[15/50],Step[210/469],loss:0.03263,lr:0.00099
# Epoch[15/50],Step[220/469],loss:0.03211,lr:0.00099
# Epoch[15/50],Step[230/469],loss:0.02809,lr:0.00099
# Epoch[15/50],Step[240/469],loss:0.03205,lr:0.00099
# Epoch[15/50],Step[250/469],loss:0.02991,lr:0.00099
# Epoch[15/50],Step[260/469],loss:0.02379,lr:0.00099
# Epoch[15/50],Step[270/469],loss:0.02970,lr:0.00099
# Epoch[15/50],Step[280/469],loss:0.03102,lr:0.00099
# Epoch[15/50],Step[290/469],loss:0.03374,lr:0.00099
# Epoch[15/50],Step[300/469],loss:0.03803,lr:0.00099
# Epoch[15/50],Step[310/469],loss:0.03743,lr:0.00099
# Epoch[15/50],Step[320/469],loss:0.02759,lr:0.00099
# Epoch[15/50],Step[330/469],loss:0.03242,lr:0.00099
# Epoch[15/50],Step[340/469],loss:0.03228,lr:0.00099
# Epoch[15/50],Step[350/469],loss:0.03154,lr:0.00099
# Epoch[15/50],Step[360/469],loss:0.03333,lr:0.00099
# Epoch[15/50],Step[370/469],loss:0.02816,lr:0.00099
# Epoch[15/50],Step[380/469],loss:0.03008,lr:0.00099
# Epoch[15/50],Step[390/469],loss:0.03206,lr:0.00099
# Epoch[15/50],Step[400/469],loss:0.03022,lr:0.00099
# Epoch[15/50],Step[410/469],loss:0.02664,lr:0.00099
# Epoch[15/50],Step[420/469],loss:0.03424,lr:0.00099
# Epoch[15/50],Step[430/469],loss:0.03245,lr:0.00099
# Epoch[15/50],Step[440/469],loss:0.03008,lr:0.00099
# Epoch[15/50],Step[450/469],loss:0.03207,lr:0.00099
# Epoch[15/50],Step[460/469],loss:0.03001,lr:0.00099
# Epoch[16/50],Step[0/469],loss:0.03203,lr:0.00099
# Epoch[16/50],Step[10/469],loss:0.02645,lr:0.00099
# Epoch[16/50],Step[20/469],loss:0.03182,lr:0.00099
# Epoch[16/50],Step[30/469],loss:0.03213,lr:0.00099
# Epoch[16/50],Step[40/469],loss:0.02676,lr:0.00099
# Epoch[16/50],Step[50/469],loss:0.02826,lr:0.00099
# Epoch[16/50],Step[60/469],loss:0.03281,lr:0.00099
# Epoch[16/50],Step[70/469],loss:0.02932,lr:0.00099
# Epoch[16/50],Step[80/469],loss:0.03666,lr:0.00099
# Epoch[16/50],Step[90/469],loss:0.03142,lr:0.00099
# Epoch[16/50],Step[100/469],loss:0.02652,lr:0.00099
# Epoch[16/50],Step[110/469],loss:0.03286,lr:0.00099
# Epoch[16/50],Step[120/469],loss:0.03070,lr:0.00099
# Epoch[16/50],Step[130/469],loss:0.02533,lr:0.00099
# Epoch[16/50],Step[140/469],loss:0.02933,lr:0.00099
# Epoch[16/50],Step[150/469],loss:0.03037,lr:0.00099
# Epoch[16/50],Step[160/469],loss:0.03009,lr:0.00099
# Epoch[16/50],Step[170/469],loss:0.02631,lr:0.00099
# Epoch[16/50],Step[180/469],loss:0.02901,lr:0.00099
# Epoch[16/50],Step[190/469],loss:0.03507,lr:0.00099
# Epoch[16/50],Step[200/469],loss:0.02890,lr:0.00099
# Epoch[16/50],Step[210/469],loss:0.03126,lr:0.00098
# Epoch[16/50],Step[220/469],loss:0.02663,lr:0.00098
# Epoch[16/50],Step[230/469],loss:0.02419,lr:0.00098
# Epoch[16/50],Step[240/469],loss:0.03481,lr:0.00098
# Epoch[16/50],Step[250/469],loss:0.02720,lr:0.00098
# Epoch[16/50],Step[260/469],loss:0.03423,lr:0.00098
# Epoch[16/50],Step[270/469],loss:0.02557,lr:0.00098
# Epoch[16/50],Step[280/469],loss:0.03011,lr:0.00098
# Epoch[16/50],Step[290/469],loss:0.02962,lr:0.00098
# Epoch[16/50],Step[300/469],loss:0.02905,lr:0.00098
# Epoch[16/50],Step[310/469],loss:0.03033,lr:0.00098
# Epoch[16/50],Step[320/469],loss:0.04518,lr:0.00098
# Epoch[16/50],Step[330/469],loss:0.03804,lr:0.00098
# Epoch[16/50],Step[340/469],loss:0.02661,lr:0.00098
# Epoch[16/50],Step[350/469],loss:0.03349,lr:0.00098
# Epoch[16/50],Step[360/469],loss:0.03802,lr:0.00098
# Epoch[16/50],Step[370/469],loss:0.02786,lr:0.00098
# Epoch[16/50],Step[380/469],loss:0.03155,lr:0.00098
# Epoch[16/50],Step[390/469],loss:0.03170,lr:0.00098
# Epoch[16/50],Step[400/469],loss:0.03733,lr:0.00098
# Epoch[16/50],Step[410/469],loss:0.03197,lr:0.00098
# Epoch[16/50],Step[420/469],loss:0.02693,lr:0.00098
# Epoch[16/50],Step[430/469],loss:0.03565,lr:0.00098
# Epoch[16/50],Step[440/469],loss:0.02915,lr:0.00098
# Epoch[16/50],Step[450/469],loss:0.02284,lr:0.00098
# Epoch[16/50],Step[460/469],loss:0.02683,lr:0.00098
# Epoch[17/50],Step[0/469],loss:0.02521,lr:0.00098
# Epoch[17/50],Step[10/469],loss:0.02800,lr:0.00098
# Epoch[17/50],Step[20/469],loss:0.03192,lr:0.00098
# Epoch[17/50],Step[30/469],loss:0.02455,lr:0.00098
# Epoch[17/50],Step[40/469],loss:0.02907,lr:0.00098
# Epoch[17/50],Step[50/469],loss:0.02689,lr:0.00098
# Epoch[17/50],Step[60/469],loss:0.03062,lr:0.00098
# Epoch[17/50],Step[70/469],loss:0.02634,lr:0.00098
# Epoch[17/50],Step[80/469],loss:0.02639,lr:0.00098
# Epoch[17/50],Step[90/469],loss:0.03011,lr:0.00098
# Epoch[17/50],Step[100/469],loss:0.02598,lr:0.00098
# Epoch[17/50],Step[110/469],loss:0.03005,lr:0.00098
# Epoch[17/50],Step[120/469],loss:0.02904,lr:0.00098
# Epoch[17/50],Step[130/469],loss:0.03104,lr:0.00098
# Epoch[17/50],Step[140/469],loss:0.02886,lr:0.00097
# Epoch[17/50],Step[150/469],loss:0.02682,lr:0.00097
# Epoch[17/50],Step[160/469],loss:0.03130,lr:0.00097
# Epoch[17/50],Step[170/469],loss:0.03034,lr:0.00097
# Epoch[17/50],Step[180/469],loss:0.02739,lr:0.00097
# Epoch[17/50],Step[190/469],loss:0.03084,lr:0.00097
# Epoch[17/50],Step[200/469],loss:0.02891,lr:0.00097
# Epoch[17/50],Step[210/469],loss:0.03062,lr:0.00097
# Epoch[17/50],Step[220/469],loss:0.03071,lr:0.00097
# Epoch[17/50],Step[230/469],loss:0.03546,lr:0.00097
# Epoch[17/50],Step[240/469],loss:0.03454,lr:0.00097
# Epoch[17/50],Step[250/469],loss:0.02745,lr:0.00097
# Epoch[17/50],Step[260/469],loss:0.02853,lr:0.00097
# Epoch[17/50],Step[270/469],loss:0.02518,lr:0.00097
# Epoch[17/50],Step[280/469],loss:0.03375,lr:0.00097
# Epoch[17/50],Step[290/469],loss:0.02705,lr:0.00097
# Epoch[17/50],Step[300/469],loss:0.03068,lr:0.00097
# Epoch[17/50],Step[310/469],loss:0.03205,lr:0.00097
# Epoch[17/50],Step[320/469],loss:0.03211,lr:0.00097
# Epoch[17/50],Step[330/469],loss:0.03310,lr:0.00097
# Epoch[17/50],Step[340/469],loss:0.02937,lr:0.00097
# Epoch[17/50],Step[350/469],loss:0.03116,lr:0.00097
# Epoch[17/50],Step[360/469],loss:0.02478,lr:0.00097
# Epoch[17/50],Step[370/469],loss:0.02582,lr:0.00097
# Epoch[17/50],Step[380/469],loss:0.02523,lr:0.00097
# Epoch[17/50],Step[390/469],loss:0.02917,lr:0.00097
# Epoch[17/50],Step[400/469],loss:0.03251,lr:0.00097
# Epoch[17/50],Step[410/469],loss:0.03274,lr:0.00097
# Epoch[17/50],Step[420/469],loss:0.02562,lr:0.00097
# Epoch[17/50],Step[430/469],loss:0.02642,lr:0.00097
# Epoch[17/50],Step[440/469],loss:0.02456,lr:0.00097
# Epoch[17/50],Step[450/469],loss:0.02989,lr:0.00097
# Epoch[17/50],Step[460/469],loss:0.03426,lr:0.00097
# Epoch[18/50],Step[0/469],loss:0.02634,lr:0.00096
# Epoch[18/50],Step[10/469],loss:0.03150,lr:0.00096
# Epoch[18/50],Step[20/469],loss:0.02619,lr:0.00096
# Epoch[18/50],Step[30/469],loss:0.02580,lr:0.00096
# Epoch[18/50],Step[40/469],loss:0.02759,lr:0.00096
# Epoch[18/50],Step[50/469],loss:0.02917,lr:0.00096
# Epoch[18/50],Step[60/469],loss:0.02501,lr:0.00096
# Epoch[18/50],Step[70/469],loss:0.02726,lr:0.00096
# Epoch[18/50],Step[80/469],loss:0.03200,lr:0.00096
# Epoch[18/50],Step[90/469],loss:0.02760,lr:0.00096
# Epoch[18/50],Step[100/469],loss:0.03063,lr:0.00096
# Epoch[18/50],Step[110/469],loss:0.03015,lr:0.00096
# Epoch[18/50],Step[120/469],loss:0.03122,lr:0.00096
# Epoch[18/50],Step[130/469],loss:0.02726,lr:0.00096
# Epoch[18/50],Step[140/469],loss:0.03116,lr:0.00096
# Epoch[18/50],Step[150/469],loss:0.03366,lr:0.00096
# Epoch[18/50],Step[160/469],loss:0.02385,lr:0.00096
# Epoch[18/50],Step[170/469],loss:0.02543,lr:0.00096
# Epoch[18/50],Step[180/469],loss:0.02400,lr:0.00096
# Epoch[18/50],Step[190/469],loss:0.02803,lr:0.00096
# Epoch[18/50],Step[200/469],loss:0.02593,lr:0.00096
# Epoch[18/50],Step[210/469],loss:0.03336,lr:0.00096
# Epoch[18/50],Step[220/469],loss:0.03197,lr:0.00096
# Epoch[18/50],Step[230/469],loss:0.02751,lr:0.00096
# Epoch[18/50],Step[240/469],loss:0.03899,lr:0.00096
# Epoch[18/50],Step[250/469],loss:0.03258,lr:0.00096
# Epoch[18/50],Step[260/469],loss:0.02780,lr:0.00096
# Epoch[18/50],Step[270/469],loss:0.02732,lr:0.00096
# Epoch[18/50],Step[280/469],loss:0.03260,lr:0.00096
# Epoch[18/50],Step[290/469],loss:0.03312,lr:0.00095
# Epoch[18/50],Step[300/469],loss:0.02938,lr:0.00095
# Epoch[18/50],Step[310/469],loss:0.03211,lr:0.00095
# Epoch[18/50],Step[320/469],loss:0.02649,lr:0.00095
# Epoch[18/50],Step[330/469],loss:0.02475,lr:0.00095
# Epoch[18/50],Step[340/469],loss:0.02626,lr:0.00095
# Epoch[18/50],Step[350/469],loss:0.02799,lr:0.00095
# Epoch[18/50],Step[360/469],loss:0.03119,lr:0.00095
# Epoch[18/50],Step[370/469],loss:0.03423,lr:0.00095
# Epoch[18/50],Step[380/469],loss:0.03050,lr:0.00095
# Epoch[18/50],Step[390/469],loss:0.03225,lr:0.00095
# Epoch[18/50],Step[400/469],loss:0.02873,lr:0.00095
# Epoch[18/50],Step[410/469],loss:0.02669,lr:0.00095
# Epoch[18/50],Step[420/469],loss:0.02850,lr:0.00095
# Epoch[18/50],Step[430/469],loss:0.03453,lr:0.00095
# Epoch[18/50],Step[440/469],loss:0.02791,lr:0.00095
# Epoch[18/50],Step[450/469],loss:0.03218,lr:0.00095
# Epoch[18/50],Step[460/469],loss:0.02351,lr:0.00095
# Epoch[19/50],Step[0/469],loss:0.02591,lr:0.00095
# Epoch[19/50],Step[10/469],loss:0.02505,lr:0.00095
# Epoch[19/50],Step[20/469],loss:0.02933,lr:0.00095
# Epoch[19/50],Step[30/469],loss:0.03194,lr:0.00095
# Epoch[19/50],Step[40/469],loss:0.02669,lr:0.00095
# Epoch[19/50],Step[50/469],loss:0.03020,lr:0.00095
# Epoch[19/50],Step[60/469],loss:0.02546,lr:0.00095
# Epoch[19/50],Step[70/469],loss:0.02704,lr:0.00094
# Epoch[19/50],Step[80/469],loss:0.03494,lr:0.00094
# Epoch[19/50],Step[90/469],loss:0.02710,lr:0.00094
# Epoch[19/50],Step[100/469],loss:0.02601,lr:0.00094
# Epoch[19/50],Step[110/469],loss:0.02744,lr:0.00094
# Epoch[19/50],Step[120/469],loss:0.03084,lr:0.00094
# Epoch[19/50],Step[130/469],loss:0.03386,lr:0.00094
# Epoch[19/50],Step[140/469],loss:0.02850,lr:0.00094
# Epoch[19/50],Step[150/469],loss:0.03407,lr:0.00094
# Epoch[19/50],Step[160/469],loss:0.03190,lr:0.00094
# Epoch[19/50],Step[170/469],loss:0.03174,lr:0.00094
# Epoch[19/50],Step[180/469],loss:0.03001,lr:0.00094
# Epoch[19/50],Step[190/469],loss:0.02914,lr:0.00094
# Epoch[19/50],Step[200/469],loss:0.03534,lr:0.00094
# Epoch[19/50],Step[210/469],loss:0.02878,lr:0.00094
# Epoch[19/50],Step[220/469],loss:0.02700,lr:0.00094
# Epoch[19/50],Step[230/469],loss:0.02481,lr:0.00094
# Epoch[19/50],Step[240/469],loss:0.02741,lr:0.00094
# Epoch[19/50],Step[250/469],loss:0.02776,lr:0.00094
# Epoch[19/50],Step[260/469],loss:0.02958,lr:0.00094
# Epoch[19/50],Step[270/469],loss:0.02665,lr:0.00094
# Epoch[19/50],Step[280/469],loss:0.02743,lr:0.00094
# Epoch[19/50],Step[290/469],loss:0.02881,lr:0.00094
# Epoch[19/50],Step[300/469],loss:0.02551,lr:0.00094
# Epoch[19/50],Step[310/469],loss:0.02765,lr:0.00093
# Epoch[19/50],Step[320/469],loss:0.02924,lr:0.00093
# Epoch[19/50],Step[330/469],loss:0.02922,lr:0.00093
# Epoch[19/50],Step[340/469],loss:0.03324,lr:0.00093
# Epoch[19/50],Step[350/469],loss:0.02750,lr:0.00093
# Epoch[19/50],Step[360/469],loss:0.02425,lr:0.00093
# Epoch[19/50],Step[370/469],loss:0.02713,lr:0.00093
# Epoch[19/50],Step[380/469],loss:0.02767,lr:0.00093
# Epoch[19/50],Step[390/469],loss:0.03238,lr:0.00093
# Epoch[19/50],Step[400/469],loss:0.02888,lr:0.00093
# Epoch[19/50],Step[410/469],loss:0.03010,lr:0.00093
# Epoch[19/50],Step[420/469],loss:0.02819,lr:0.00093
# Epoch[19/50],Step[430/469],loss:0.03034,lr:0.00093
# Epoch[19/50],Step[440/469],loss:0.02932,lr:0.00093
# Epoch[19/50],Step[450/469],loss:0.02771,lr:0.00093
# Epoch[19/50],Step[460/469],loss:0.03097,lr:0.00093
# Epoch[20/50],Step[0/469],loss:0.03486,lr:0.00093
# Epoch[20/50],Step[10/469],loss:0.02648,lr:0.00093
# Epoch[20/50],Step[20/469],loss:0.02704,lr:0.00093
# Epoch[20/50],Step[30/469],loss:0.03164,lr:0.00093
# Epoch[20/50],Step[40/469],loss:0.02759,lr:0.00093
# Epoch[20/50],Step[50/469],loss:0.02791,lr:0.00093
# Epoch[20/50],Step[60/469],loss:0.03072,lr:0.00092
# Epoch[20/50],Step[70/469],loss:0.03140,lr:0.00092
# Epoch[20/50],Step[80/469],loss:0.03032,lr:0.00092
# Epoch[20/50],Step[90/469],loss:0.03472,lr:0.00092
# Epoch[20/50],Step[100/469],loss:0.03372,lr:0.00092
# Epoch[20/50],Step[110/469],loss:0.02895,lr:0.00092
# Epoch[20/50],Step[120/469],loss:0.02924,lr:0.00092
# Epoch[20/50],Step[130/469],loss:0.03510,lr:0.00092
# Epoch[20/50],Step[140/469],loss:0.02331,lr:0.00092
# Epoch[20/50],Step[150/469],loss:0.02540,lr:0.00092
# Epoch[20/50],Step[160/469],loss:0.03012,lr:0.00092
# Epoch[20/50],Step[170/469],loss:0.03135,lr:0.00092
# Epoch[20/50],Step[180/469],loss:0.03174,lr:0.00092
# Epoch[20/50],Step[190/469],loss:0.03257,lr:0.00092
# Epoch[20/50],Step[200/469],loss:0.02796,lr:0.00092
# Epoch[20/50],Step[210/469],loss:0.02599,lr:0.00092
# Epoch[20/50],Step[220/469],loss:0.02963,lr:0.00092
# Epoch[20/50],Step[230/469],loss:0.03031,lr:0.00092
# Epoch[20/50],Step[240/469],loss:0.02764,lr:0.00092
# Epoch[20/50],Step[250/469],loss:0.02883,lr:0.00092
# Epoch[20/50],Step[260/469],loss:0.02987,lr:0.00092
# Epoch[20/50],Step[270/469],loss:0.02401,lr:0.00091
# Epoch[20/50],Step[280/469],loss:0.02808,lr:0.00091
# Epoch[20/50],Step[290/469],loss:0.02983,lr:0.00091
# Epoch[20/50],Step[300/469],loss:0.02837,lr:0.00091
# Epoch[20/50],Step[310/469],loss:0.02815,lr:0.00091
# Epoch[20/50],Step[320/469],loss:0.02601,lr:0.00091
# Epoch[20/50],Step[330/469],loss:0.02964,lr:0.00091
# Epoch[20/50],Step[340/469],loss:0.02598,lr:0.00091
# Epoch[20/50],Step[350/469],loss:0.02685,lr:0.00091
# Epoch[20/50],Step[360/469],loss:0.03362,lr:0.00091
# Epoch[20/50],Step[370/469],loss:0.03016,lr:0.00091
# Epoch[20/50],Step[380/469],loss:0.02933,lr:0.00091
# Epoch[20/50],Step[390/469],loss:0.03315,lr:0.00091
# Epoch[20/50],Step[400/469],loss:0.03450,lr:0.00091
# Epoch[20/50],Step[410/469],loss:0.02731,lr:0.00091
# Epoch[20/50],Step[420/469],loss:0.02678,lr:0.00091
# Epoch[20/50],Step[430/469],loss:0.02468,lr:0.00091
# Epoch[20/50],Step[440/469],loss:0.02668,lr:0.00091
# Epoch[20/50],Step[450/469],loss:0.02966,lr:0.00091
# Epoch[20/50],Step[460/469],loss:0.02969,lr:0.00090
# Epoch[21/50],Step[0/469],loss:0.02651,lr:0.00090
# Epoch[21/50],Step[10/469],loss:0.02709,lr:0.00090
# Epoch[21/50],Step[20/469],loss:0.02550,lr:0.00090
# Epoch[21/50],Step[30/469],loss:0.02770,lr:0.00090
# Epoch[21/50],Step[40/469],loss:0.02611,lr:0.00090
# Epoch[21/50],Step[50/469],loss:0.03146,lr:0.00090
# Epoch[21/50],Step[60/469],loss:0.02632,lr:0.00090
# Epoch[21/50],Step[70/469],loss:0.02614,lr:0.00090
# Epoch[21/50],Step[80/469],loss:0.03161,lr:0.00090
# Epoch[21/50],Step[90/469],loss:0.02600,lr:0.00090
# Epoch[21/50],Step[100/469],loss:0.02364,lr:0.00090
# Epoch[21/50],Step[110/469],loss:0.02799,lr:0.00090
# Epoch[21/50],Step[120/469],loss:0.02861,lr:0.00090
# Epoch[21/50],Step[130/469],loss:0.02775,lr:0.00090
# ...
# Epoch[44/50],Step[140/469],loss:0.02275,lr:0.00008
# Epoch[44/50],Step[150/469],loss:0.02429,lr:0.00008
# Epoch[44/50],Step[160/469],loss:0.02754,lr:0.00008
# Epoch[44/50],Step[170/469],loss:0.02871,lr:0.00008
# Epoch[44/50],Step[180/469],loss:0.02388,lr:0.00007
# Epoch[44/50],Step[190/469],loss:0.02476,lr:0.00007
# Epoch[44/50],Step[200/469],loss:0.02641,lr:0.00007
# Epoch[44/50],Step[210/469],loss:0.02752,lr:0.00007
# Epoch[44/50],Step[220/469],loss:0.02449,lr:0.00007
# Epoch[44/50],Step[230/469],loss:0.02677,lr:0.00007
# Epoch[44/50],Step[240/469],loss:0.02325,lr:0.00007
# Epoch[44/50],Step[250/469],loss:0.02408,lr:0.00007
# Epoch[44/50],Step[260/469],loss:0.02621,lr:0.00007
# Epoch[44/50],Step[270/469],loss:0.02698,lr:0.00007
# Epoch[44/50],Step[280/469],loss:0.02705,lr:0.00007
# Epoch[44/50],Step[290/469],loss:0.02645,lr:0.00007
# Epoch[44/50],Step[300/469],loss:0.02699,lr:0.00007
# Epoch[44/50],Step[310/469],loss:0.02583,lr:0.00007
# Epoch[44/50],Step[320/469],loss:0.02734,lr:0.00007
# Epoch[44/50],Step[330/469],loss:0.02495,lr:0.00007
# Epoch[44/50],Step[340/469],loss:0.02424,lr:0.00007
# Epoch[44/50],Step[350/469],loss:0.02119,lr:0.00007
# Epoch[44/50],Step[360/469],loss:0.02608,lr:0.00007
# Epoch[44/50],Step[370/469],loss:0.01885,lr:0.00007
# Epoch[44/50],Step[380/469],loss:0.02319,lr:0.00007
# Epoch[44/50],Step[390/469],loss:0.02826,lr:0.00007
# Epoch[44/50],Step[400/469],loss:0.02347,lr:0.00006
# Epoch[44/50],Step[410/469],loss:0.02471,lr:0.00006
# Epoch[44/50],Step[420/469],loss:0.02504,lr:0.00006
# Epoch[44/50],Step[430/469],loss:0.02510,lr:0.00006
# Epoch[44/50],Step[440/469],loss:0.02285,lr:0.00006
# Epoch[44/50],Step[450/469],loss:0.02930,lr:0.00006
# Epoch[44/50],Step[460/469],loss:0.03212,lr:0.00006
# Epoch[45/50],Step[0/469],loss:0.02837,lr:0.00006
# Epoch[45/50],Step[10/469],loss:0.02758,lr:0.00006
# Epoch[45/50],Step[20/469],loss:0.02827,lr:0.00006
# Epoch[45/50],Step[30/469],loss:0.02528,lr:0.00006
# Epoch[45/50],Step[40/469],loss:0.02493,lr:0.00006
# Epoch[45/50],Step[50/469],loss:0.02533,lr:0.00006
# Epoch[45/50],Step[60/469],loss:0.02539,lr:0.00006
# Epoch[45/50],Step[70/469],loss:0.02465,lr:0.00006
# Epoch[45/50],Step[80/469],loss:0.02244,lr:0.00006
# Epoch[45/50],Step[90/469],loss:0.02331,lr:0.00006
# Epoch[45/50],Step[100/469],loss:0.02669,lr:0.00006
# Epoch[45/50],Step[110/469],loss:0.02586,lr:0.00006
# Epoch[45/50],Step[120/469],loss:0.02780,lr:0.00006
# Epoch[45/50],Step[130/469],loss:0.02599,lr:0.00006
# Epoch[45/50],Step[140/469],loss:0.02049,lr:0.00006
# Epoch[45/50],Step[150/469],loss:0.02118,lr:0.00006
# Epoch[45/50],Step[160/469],loss:0.02128,lr:0.00006
# Epoch[45/50],Step[170/469],loss:0.02802,lr:0.00005
# Epoch[45/50],Step[180/469],loss:0.02690,lr:0.00005
# Epoch[45/50],Step[190/469],loss:0.02653,lr:0.00005
# Epoch[45/50],Step[200/469],loss:0.02458,lr:0.00005
# Epoch[45/50],Step[210/469],loss:0.02415,lr:0.00005
# Epoch[45/50],Step[220/469],loss:0.02297,lr:0.00005
# Epoch[45/50],Step[230/469],loss:0.02404,lr:0.00005
# Epoch[45/50],Step[240/469],loss:0.02273,lr:0.00005
# Epoch[45/50],Step[250/469],loss:0.02424,lr:0.00005
# Epoch[45/50],Step[260/469],loss:0.02419,lr:0.00005
# Epoch[45/50],Step[270/469],loss:0.02445,lr:0.00005
# Epoch[45/50],Step[280/469],loss:0.02439,lr:0.00005
# Epoch[45/50],Step[290/469],loss:0.02567,lr:0.00005
# Epoch[45/50],Step[300/469],loss:0.02609,lr:0.00005
# Epoch[45/50],Step[310/469],loss:0.02267,lr:0.00005
# Epoch[45/50],Step[320/469],loss:0.02025,lr:0.00005
# Epoch[45/50],Step[330/469],loss:0.02456,lr:0.00005
# Epoch[45/50],Step[340/469],loss:0.02591,lr:0.00005
# Epoch[45/50],Step[350/469],loss:0.02842,lr:0.00005
# Epoch[45/50],Step[360/469],loss:0.02534,lr:0.00005
# Epoch[45/50],Step[370/469],loss:0.02394,lr:0.00005
# Epoch[45/50],Step[380/469],loss:0.02734,lr:0.00005
# Epoch[45/50],Step[390/469],loss:0.02590,lr:0.00005
# Epoch[45/50],Step[400/469],loss:0.02258,lr:0.00005
# Epoch[45/50],Step[410/469],loss:0.02941,lr:0.00005
# Epoch[45/50],Step[420/469],loss:0.02416,lr:0.00004
# Epoch[45/50],Step[430/469],loss:0.02837,lr:0.00004
# Epoch[45/50],Step[440/469],loss:0.02156,lr:0.00004
# Epoch[45/50],Step[450/469],loss:0.02094,lr:0.00004
# Epoch[45/50],Step[460/469],loss:0.02344,lr:0.00004
# Epoch[46/50],Step[0/469],loss:0.02872,lr:0.00004
# Epoch[46/50],Step[10/469],loss:0.02967,lr:0.00004
# Epoch[46/50],Step[20/469],loss:0.02725,lr:0.00004
# Epoch[46/50],Step[30/469],loss:0.02387,lr:0.00004
# Epoch[46/50],Step[40/469],loss:0.02600,lr:0.00004
# Epoch[46/50],Step[50/469],loss:0.02670,lr:0.00004
# Epoch[46/50],Step[60/469],loss:0.02280,lr:0.00004
# Epoch[46/50],Step[70/469],loss:0.02341,lr:0.00004
# Epoch[46/50],Step[80/469],loss:0.02570,lr:0.00004
# Epoch[46/50],Step[90/469],loss:0.02392,lr:0.00004
# Epoch[46/50],Step[100/469],loss:0.02634,lr:0.00004
# Epoch[46/50],Step[110/469],loss:0.02285,lr:0.00004
# Epoch[46/50],Step[120/469],loss:0.02612,lr:0.00004
# Epoch[46/50],Step[130/469],loss:0.01940,lr:0.00004
# Epoch[46/50],Step[140/469],loss:0.02510,lr:0.00004
# Epoch[46/50],Step[150/469],loss:0.02662,lr:0.00004
# Epoch[46/50],Step[160/469],loss:0.02392,lr:0.00004
# Epoch[46/50],Step[170/469],loss:0.02528,lr:0.00004
# Epoch[46/50],Step[180/469],loss:0.02242,lr:0.00004
# Epoch[46/50],Step[190/469],loss:0.02650,lr:0.00004
# Epoch[46/50],Step[200/469],loss:0.02687,lr:0.00004
# Epoch[46/50],Step[210/469],loss:0.02642,lr:0.00004
# Epoch[46/50],Step[220/469],loss:0.02544,lr:0.00004
# Epoch[46/50],Step[230/469],loss:0.02949,lr:0.00004
# Epoch[46/50],Step[240/469],loss:0.02315,lr:0.00003
# Epoch[46/50],Step[250/469],loss:0.02135,lr:0.00003
# Epoch[46/50],Step[260/469],loss:0.02537,lr:0.00003
# Epoch[46/50],Step[270/469],loss:0.02572,lr:0.00003
# Epoch[46/50],Step[280/469],loss:0.02236,lr:0.00003
# Epoch[46/50],Step[290/469],loss:0.02558,lr:0.00003
# Epoch[46/50],Step[300/469],loss:0.02412,lr:0.00003
# Epoch[46/50],Step[310/469],loss:0.02211,lr:0.00003
# Epoch[46/50],Step[320/469],loss:0.02445,lr:0.00003
# Epoch[46/50],Step[330/469],loss:0.02571,lr:0.00003
# Epoch[46/50],Step[340/469],loss:0.02432,lr:0.00003
# Epoch[46/50],Step[350/469],loss:0.02792,lr:0.00003
# Epoch[46/50],Step[360/469],loss:0.02200,lr:0.00003
# Epoch[46/50],Step[370/469],loss:0.02642,lr:0.00003
# Epoch[46/50],Step[380/469],loss:0.02307,lr:0.00003
# Epoch[46/50],Step[390/469],loss:0.02837,lr:0.00003
# Epoch[46/50],Step[400/469],loss:0.02422,lr:0.00003
# Epoch[46/50],Step[410/469],loss:0.02772,lr:0.00003
# Epoch[46/50],Step[420/469],loss:0.02964,lr:0.00003
# Epoch[46/50],Step[430/469],loss:0.02940,lr:0.00003
# Epoch[46/50],Step[440/469],loss:0.02798,lr:0.00003
# Epoch[46/50],Step[450/469],loss:0.02630,lr:0.00003
# Epoch[46/50],Step[460/469],loss:0.02356,lr:0.00003
# Epoch[47/50],Step[0/469],loss:0.02438,lr:0.00003
# Epoch[47/50],Step[10/469],loss:0.02313,lr:0.00003
# Epoch[47/50],Step[20/469],loss:0.02533,lr:0.00003
# Epoch[47/50],Step[30/469],loss:0.02667,lr:0.00003
# Epoch[47/50],Step[40/469],loss:0.02608,lr:0.00003
# Epoch[47/50],Step[50/469],loss:0.02290,lr:0.00003
# Epoch[47/50],Step[60/469],loss:0.02834,lr:0.00003
# Epoch[47/50],Step[70/469],loss:0.02689,lr:0.00003
# Epoch[47/50],Step[80/469],loss:0.02810,lr:0.00003
# Epoch[47/50],Step[90/469],loss:0.02365,lr:0.00003
# Epoch[47/50],Step[100/469],loss:0.02317,lr:0.00002
# Epoch[47/50],Step[110/469],loss:0.02565,lr:0.00002
# Epoch[47/50],Step[120/469],loss:0.02489,lr:0.00002
# Epoch[47/50],Step[130/469],loss:0.02366,lr:0.00002
# Epoch[47/50],Step[140/469],loss:0.02469,lr:0.00002
# Epoch[47/50],Step[150/469],loss:0.02653,lr:0.00002
# Epoch[47/50],Step[160/469],loss:0.02478,lr:0.00002
# Epoch[47/50],Step[170/469],loss:0.02336,lr:0.00002
# Epoch[47/50],Step[180/469],loss:0.02378,lr:0.00002
# Epoch[47/50],Step[190/469],loss:0.02171,lr:0.00002
# Epoch[47/50],Step[200/469],loss:0.02526,lr:0.00002
# Epoch[47/50],Step[210/469],loss:0.02414,lr:0.00002
# Epoch[47/50],Step[220/469],loss:0.02165,lr:0.00002
# Epoch[47/50],Step[230/469],loss:0.02268,lr:0.00002
# Epoch[47/50],Step[240/469],loss:0.02335,lr:0.00002
# Epoch[47/50],Step[250/469],loss:0.02378,lr:0.00002
# Epoch[47/50],Step[260/469],loss:0.02240,lr:0.00002
# Epoch[47/50],Step[270/469],loss:0.02289,lr:0.00002
# Epoch[47/50],Step[280/469],loss:0.02183,lr:0.00002
# Epoch[47/50],Step[290/469],loss:0.02927,lr:0.00002
# Epoch[47/50],Step[300/469],loss:0.02355,lr:0.00002
# Epoch[47/50],Step[310/469],loss:0.02420,lr:0.00002
# Epoch[47/50],Step[320/469],loss:0.02622,lr:0.00002
# Epoch[47/50],Step[330/469],loss:0.02173,lr:0.00002
# Epoch[47/50],Step[340/469],loss:0.02074,lr:0.00002
# Epoch[47/50],Step[350/469],loss:0.02440,lr:0.00002
# Epoch[47/50],Step[360/469],loss:0.03498,lr:0.00002
# Epoch[47/50],Step[370/469],loss:0.02524,lr:0.00002
# Epoch[47/50],Step[380/469],loss:0.02483,lr:0.00002
# Epoch[47/50],Step[390/469],loss:0.02711,lr:0.00002
# Epoch[47/50],Step[400/469],loss:0.03083,lr:0.00002
# Epoch[47/50],Step[410/469],loss:0.02417,lr:0.00002
# Epoch[47/50],Step[420/469],loss:0.02659,lr:0.00002
# Epoch[47/50],Step[430/469],loss:0.01946,lr:0.00002
# Epoch[47/50],Step[440/469],loss:0.02229,lr:0.00002
# Epoch[47/50],Step[450/469],loss:0.02454,lr:0.00002
# Epoch[47/50],Step[460/469],loss:0.02143,lr:0.00002
# Epoch[48/50],Step[0/469],loss:0.02700,lr:0.00002
# Epoch[48/50],Step[10/469],loss:0.02468,lr:0.00002
# Epoch[48/50],Step[20/469],loss:0.03135,lr:0.00002
# Epoch[48/50],Step[30/469],loss:0.01948,lr:0.00002
# Epoch[48/50],Step[40/469],loss:0.02220,lr:0.00001
# Epoch[48/50],Step[50/469],loss:0.02778,lr:0.00001
# Epoch[48/50],Step[60/469],loss:0.03028,lr:0.00001
# Epoch[48/50],Step[70/469],loss:0.02134,lr:0.00001
# Epoch[48/50],Step[80/469],loss:0.02496,lr:0.00001
# Epoch[48/50],Step[90/469],loss:0.02463,lr:0.00001
# Epoch[48/50],Step[100/469],loss:0.02306,lr:0.00001
# Epoch[48/50],Step[110/469],loss:0.02770,lr:0.00001
# Epoch[48/50],Step[120/469],loss:0.02875,lr:0.00001
# Epoch[48/50],Step[130/469],loss:0.01967,lr:0.00001
# Epoch[48/50],Step[140/469],loss:0.02758,lr:0.00001
# Epoch[48/50],Step[150/469],loss:0.02282,lr:0.00001
# Epoch[48/50],Step[160/469],loss:0.02481,lr:0.00001
# Epoch[48/50],Step[170/469],loss:0.02235,lr:0.00001
# Epoch[48/50],Step[180/469],loss:0.02604,lr:0.00001
# Epoch[48/50],Step[190/469],loss:0.02401,lr:0.00001
# Epoch[48/50],Step[200/469],loss:0.02567,lr:0.00001
# Epoch[48/50],Step[210/469],loss:0.02480,lr:0.00001
# Epoch[48/50],Step[220/469],loss:0.02065,lr:0.00001
# Epoch[48/50],Step[230/469],loss:0.02459,lr:0.00001
# Epoch[48/50],Step[240/469],loss:0.02708,lr:0.00001
# Epoch[48/50],Step[250/469],loss:0.02514,lr:0.00001
# Epoch[48/50],Step[260/469],loss:0.02310,lr:0.00001
# Epoch[48/50],Step[270/469],loss:0.02963,lr:0.00001
# Epoch[48/50],Step[280/469],loss:0.02223,lr:0.00001
# Epoch[48/50],Step[290/469],loss:0.02494,lr:0.00001
# Epoch[48/50],Step[300/469],loss:0.02391,lr:0.00001
# Epoch[48/50],Step[310/469],loss:0.02698,lr:0.00001
# Epoch[48/50],Step[320/469],loss:0.02699,lr:0.00001
# Epoch[48/50],Step[330/469],loss:0.02704,lr:0.00001
# Epoch[48/50],Step[340/469],loss:0.02681,lr:0.00001
# Epoch[48/50],Step[350/469],loss:0.02308,lr:0.00001
# Epoch[48/50],Step[360/469],loss:0.02391,lr:0.00001
# Epoch[48/50],Step[370/469],loss:0.02165,lr:0.00001
# Epoch[48/50],Step[380/469],loss:0.02613,lr:0.00001
# Epoch[48/50],Step[390/469],loss:0.02559,lr:0.00001
# Epoch[48/50],Step[400/469],loss:0.02632,lr:0.00001
# Epoch[48/50],Step[410/469],loss:0.02901,lr:0.00001
# Epoch[48/50],Step[420/469],loss:0.02155,lr:0.00001
# Epoch[48/50],Step[430/469],loss:0.02543,lr:0.00001
# Epoch[48/50],Step[440/469],loss:0.02201,lr:0.00001
# Epoch[48/50],Step[450/469],loss:0.02352,lr:0.00001
# Epoch[48/50],Step[460/469],loss:0.02349,lr:0.00001
# Epoch[49/50],Step[0/469],loss:0.02752,lr:0.00001
# Epoch[49/50],Step[10/469],loss:0.02306,lr:0.00001
# Epoch[49/50],Step[20/469],loss:0.02076,lr:0.00001
# Epoch[49/50],Step[30/469],loss:0.02353,lr:0.00001
# Epoch[49/50],Step[40/469],loss:0.02177,lr:0.00001
# Epoch[49/50],Step[50/469],loss:0.02402,lr:0.00001
# Epoch[49/50],Step[60/469],loss:0.02626,lr:0.00001
# Epoch[49/50],Step[70/469],loss:0.02260,lr:0.00001
# Epoch[49/50],Step[80/469],loss:0.02626,lr:0.00001
# Epoch[49/50],Step[90/469],loss:0.02881,lr:0.00001
# Epoch[49/50],Step[100/469],loss:0.02325,lr:0.00001
# Epoch[49/50],Step[110/469],loss:0.02945,lr:0.00001
# Epoch[49/50],Step[120/469],loss:0.02713,lr:0.00001
# Epoch[49/50],Step[130/469],loss:0.02709,lr:0.00001
# Epoch[49/50],Step[140/469],loss:0.02323,lr:0.00001
# Epoch[49/50],Step[150/469],loss:0.02034,lr:0.00000
# Epoch[49/50],Step[160/469],loss:0.02786,lr:0.00000
# Epoch[49/50],Step[170/469],loss:0.02682,lr:0.00000
# Epoch[49/50],Step[180/469],loss:0.02782,lr:0.00000
# Epoch[49/50],Step[190/469],loss:0.02507,lr:0.00000
# Epoch[49/50],Step[200/469],loss:0.02874,lr:0.00000
# Epoch[49/50],Step[210/469],loss:0.02484,lr:0.00000
# Epoch[49/50],Step[220/469],loss:0.02306,lr:0.00000
# Epoch[49/50],Step[230/469],loss:0.02201,lr:0.00000
# Epoch[49/50],Step[240/469],loss:0.02185,lr:0.00000
# Epoch[49/50],Step[250/469],loss:0.03013,lr:0.00000
# Epoch[49/50],Step[260/469],loss:0.02451,lr:0.00000
# Epoch[49/50],Step[270/469],loss:0.02267,lr:0.00000
# Epoch[49/50],Step[280/469],loss:0.02371,lr:0.00000
# Epoch[49/50],Step[290/469],loss:0.03042,lr:0.00000
# Epoch[49/50],Step[300/469],loss:0.02503,lr:0.00000
# Epoch[49/50],Step[310/469],loss:0.02182,lr:0.00000
# Epoch[49/50],Step[320/469],loss:0.02476,lr:0.00000
# Epoch[49/50],Step[330/469],loss:0.02833,lr:0.00000
# Epoch[49/50],Step[340/469],loss:0.02519,lr:0.00000
# Epoch[49/50],Step[350/469],loss:0.02823,lr:0.00000
# Epoch[49/50],Step[360/469],loss:0.02543,lr:0.00000
# Epoch[49/50],Step[370/469],loss:0.02902,lr:0.00000
# Epoch[49/50],Step[380/469],loss:0.02827,lr:0.00000
# Epoch[49/50],Step[390/469],loss:0.02357,lr:0.00000
# Epoch[49/50],Step[400/469],loss:0.02878,lr:0.00000
# Epoch[49/50],Step[410/469],loss:0.02432,lr:0.00000
# Epoch[49/50],Step[420/469],loss:0.02316,lr:0.00000
# Epoch[49/50],Step[430/469],loss:0.02800,lr:0.00000
# Epoch[49/50],Step[440/469],loss:0.02842,lr:0.00000
# Epoch[49/50],Step[450/469],loss:0.02348,lr:0.00000
# Epoch[49/50],Step[460/469],loss:0.02497,lr:0.00000
# Epoch[50/50],Step[0/469],loss:0.02088,lr:0.00000
# Epoch[50/50],Step[10/469],loss:0.02756,lr:0.00000
# Epoch[50/50],Step[20/469],loss:0.02281,lr:0.00000
# Epoch[50/50],Step[30/469],loss:0.02614,lr:0.00000
# Epoch[50/50],Step[40/469],loss:0.02539,lr:0.00000
# Epoch[50/50],Step[50/469],loss:0.02021,lr:0.00000
# Epoch[50/50],Step[60/469],loss:0.02289,lr:0.00000
# Epoch[50/50],Step[70/469],loss:0.02126,lr:0.00000
# Epoch[50/50],Step[80/469],loss:0.02490,lr:0.00000
# Epoch[50/50],Step[90/469],loss:0.02688,lr:0.00000
# Epoch[50/50],Step[100/469],loss:0.02729,lr:0.00000
# Epoch[50/50],Step[110/469],loss:0.02201,lr:0.00000
# Epoch[50/50],Step[120/469],loss:0.02396,lr:0.00000
# Epoch[50/50],Step[130/469],loss:0.01749,lr:0.00000
# Epoch[50/50],Step[140/469],loss:0.02908,lr:0.00000
# Epoch[50/50],Step[150/469],loss:0.02293,lr:0.00000
# Epoch[50/50],Step[160/469],loss:0.02583,lr:0.00000
# Epoch[50/50],Step[170/469],loss:0.02641,lr:0.00000
# Epoch[50/50],Step[180/469],loss:0.02257,lr:0.00000
# Epoch[50/50],Step[190/469],loss:0.02209,lr:0.00000
# Epoch[50/50],Step[200/469],loss:0.02361,lr:0.00000
# Epoch[50/50],Step[210/469],loss:0.03043,lr:0.00000
# Epoch[50/50],Step[220/469],loss:0.02764,lr:0.00000
# Epoch[50/50],Step[230/469],loss:0.02652,lr:0.00000
# Epoch[50/50],Step[240/469],loss:0.03039,lr:0.00000
# Epoch[50/50],Step[250/469],loss:0.02059,lr:0.00000
# Epoch[50/50],Step[260/469],loss:0.02704,lr:0.00000
# Epoch[50/50],Step[270/469],loss:0.02459,lr:0.00000
# Epoch[50/50],Step[280/469],loss:0.02761,lr:0.00000
# Epoch[50/50],Step[290/469],loss:0.02594,lr:0.00000
# Epoch[50/50],Step[300/469],loss:0.02892,lr:0.00000
# Epoch[50/50],Step[310/469],loss:0.02224,lr:0.00000
# Epoch[50/50],Step[320/469],loss:0.02414,lr:0.00000
# Epoch[50/50],Step[330/469],loss:0.02694,lr:0.00000
# Epoch[50/50],Step[340/469],loss:0.02213,lr:0.00000
# Epoch[50/50],Step[350/469],loss:0.02533,lr:0.00000
# Epoch[50/50],Step[360/469],loss:0.02670,lr:0.00000
# Epoch[50/50],Step[370/469],loss:0.02599,lr:0.00000
# Epoch[50/50],Step[380/469],loss:0.02265,lr:0.00000
# Epoch[50/50],Step[390/469],loss:0.02714,lr:0.00000
# Epoch[50/50],Step[400/469],loss:0.02329,lr:0.00000
# Epoch[50/50],Step[410/469],loss:0.02524,lr:0.00000
# Epoch[50/50],Step[420/469],loss:0.02491,lr:0.00000
# Epoch[50/50],Step[430/469],loss:0.02814,lr:0.00000
# Epoch[50/50],Step[440/469],loss:0.02784,lr:0.00000
# Epoch[50/50],Step[450/469],loss:0.02720,lr:0.00000
# Epoch[50/50],Step[460/469],loss:0.02518,lr:0.00000

# %%
model.state_dict()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:398, in RepresentationPrinter.pretty(self, obj)
#     396 printer = self._in_deferred_types(cls)
#     397 if printer is not None:
# --> 398     return printer(obj, self, cycle)
#     399 else:
#     400     # Finally look for special method names.
#     401     # Some objects automatically create any requested
#     402     # attribute. Try to ignore most of them by checking for
#     403     # callability.
#     404     if '_repr_pretty_' in cls.__dict__:
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:894, in _ordereddict_pprint(obj, p, cycle)
#     892     p.pretty(cls_ctor(RawText("...")))
#     893 elif len(obj):
# --> 894     p.pretty(cls_ctor(list(obj.items())))
#     895 else:
#     896     p.pretty(cls_ctor())
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:407, in RepresentationPrinter.pretty(self, obj)
#     405     meth = cls._repr_pretty_
#     406     if callable(meth):
# --> 407         return meth(obj, self, cycle)
#     408 if cls is not object \
#     409         and callable(cls.__dict__.get('__repr__')):
#     410     return _repr_pprint(obj, self, cycle)
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:564, in CallExpression._repr_pretty_(self, p, cycle)
#     562 for arg in self.args:
#     563     new_item()
# --> 564     p.pretty(arg)
#     565 for arg_name, arg in self.kwargs.items():
#     566     new_item()
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:640, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     638         p.text(',')
#     639         p.breakable()
# --> 640     p.pretty(x)
#     641 if len(obj) == 1 and isinstance(obj, tuple):
#     642     # Special case for 1-item tuples.
#     643     p.text(',')
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:640, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     638         p.text(',')
#     639         p.breakable()
# --> 640     p.pretty(x)
#     641 if len(obj) == 1 and isinstance(obj, tuple):
#     642     # Special case for 1-item tuples.
#     643     p.text(',')
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor.py:426, in Tensor.__repr__(self, tensor_contents)
#     422     return handle_torch_function(
#     423         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     424     )
#     425 # All strings are unicode in Python 3.
# --> 426 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor_str.py:636, in _str(self, tensor_contents)
#     634 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     635     guard = torch._C._DisableFuncTorch()
# --> 636     return _str_intern(self, tensor_contents=tensor_contents)
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor_str.py:567, in _str_intern(inp, tensor_contents)
#     565                     tensor_str = _tensor_str(self.to_dense(), indent)
#     566                 else:
# --> 567                     tensor_str = _tensor_str(self, indent)
#     569 if self.layout != torch.strided:
#     570     suffixes.append("layout=" + str(self.layout))
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor_str.py:327, in _tensor_str(self, indent)
#     323     return _tensor_str_with_formatter(
#     324         self, indent, summarize, real_formatter, imag_formatter
#     325     )
#     326 else:
# --> 327     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     328     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor_str.py:116, in _Formatter.__init__(self, tensor)
#     112         self.max_width = max(self.max_width, len(value_str))
#     114 else:
#     115     nonzero_finite_vals = torch.masked_select(
# --> 116         tensor_view, torch.isfinite(tensor_view) & tensor_view.ne(0)
#     117     )
#     119     if nonzero_finite_vals.numel() == 0:
#     120         # no valid number, do nothing
#     121         return
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
torch.save(model.state_dict(), 'model.torch')
torch.save(model_ema.state_dict(), 'model_ema.torch')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 torch.save(model.state_dict(), 'model.torch')
#       2 torch.save(model_ema.state_dict(), 'model_ema.torch')
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:441, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     439 if _use_new_zipfile_serialization:
#     440     with _open_zipfile_writer(f) as opened_zipfile:
# --> 441         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442         return
#     443 else:
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:665, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     661 # given that we copy things around anyway, we might use storage.cpu()
#     662 # this means to that to get tensors serialized, you need to implement
#     663 # .cpu() on the underlying Storage
#     664 if storage.device.type != 'cpu':
# --> 665     storage = storage.cpu()
#     666 # Now that it is on the CPU we can directly copy it into the zip file
#     667 num_bytes = storage.nbytes()
#
# File /opt/conda/lib/python3.10/site-packages/torch/storage.py:121, in _StorageBase.cpu(self)
#     119 """Returns a CPU copy of this storage if it's not already on the CPU"""
#     120 if self.device.type != 'cpu':
# --> 121     return torch.UntypedStorage(self.size()).copy_(self, False)
#     122 else:
#     123     return self
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
model.load_state_dict(torch.load('model.torch'))
model_ema.load_state_dict(torch.load('model_ema.torch'))

# %%
samples=model_ema.module.sampling(n_samples, clipped_reverse_diffusion=not no_clip, device=device)
# Out:
# Sampling: 100%|██████████| 1000/1000 [00:24<00:00, 40.77it/s]

# %%
save_image(samples,"results/steps_{:0>8}.png".format(global_steps),nrow=int(math.sqrt(n_samples)))

# %%
import matplotlib.pyplot as plt

# %%
samples.shape
# Out:
# torch.Size([36, 1, 28, 28])

# %%
plt.imshow(samples[34, 0, :, :].cpu().numpy())

# %%
def reconstruct_from_noise(model, batch_size, start_noise=None, noise=None, timesteps=timesteps, clipped_reverse_diffusion=True, device="cuda"):
    x_t = start_noise.to(device)
    
    for i in tqdm(range(timesteps-1,-1,-1),desc="Reconstruct"):
        t = torch.tensor([i for _ in range(batch_size)]).to(device)

        if clipped_reverse_diffusion:
            x_t=model._reverse_diffusion_with_clip(x_t, t, noise)
        else:
            x_t=model._reverse_diffusion(x_t, t, noise)

    x_t=(x_t+1.)/2. #[-1,1] to [0,1]

    return x_t

# %%
def test_mse(model, test_loader, device, name='MSE'):
    model.eval()
    test_loss = 0
    loss_function = nn.functional.mse_loss
    with torch.no_grad():
        for i, (data, _) in enumerate(test_loader):
            data = data.to(device)
            noise = torch.randn_like(data).to(device)
            pred_noise = model(data, noise)
            recon_data = reconstruct_from_noise(model, batch_size, pred_noise, noise, clipped_reverse_diffusion=not no_clip, device=device)
            test_loss += loss_function(recon_data, data).item()

    test_loss /= len(test_loader.dataset)
    print('====> '+name+' Test set loss: {:.4f}'.format(test_loss))

# %%
data = next(iter(test_loader))[0].to(device)
noise = torch.randn_like(data).to(device)
pred_noise = model_ema(data, noise)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 data = next(iter(test_loader))[0].to(device)
#       2 noise = torch.randn_like(data).to(device)
#       3 pred_noise = model_ema(data, noise)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
plt.imshow(data[2,0].detach().cpu().numpy())

# %%
plt.imshow(noise[0,0].detach().cpu().numpy())

# %%
t = torch.tensor([i for _ in range(batch_size)]).to(device)
#recon_data = model_ema.module._reverse_diffusion(pred_noise, t, noise)
recon_data = reconstruct_from_noise(model, batch_size, pred_noise, noise, clipped_reverse_diffusion=not no_clip, device=device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 t = torch.tensor([i for _ in range(batch_size)]).to(device)
#       2 #recon_data = model_ema.module._reverse_diffusion(pred_noise, t, noise)
#       3 recon_data = reconstruct_from_noise(model, batch_size, pred_noise, noise, clipped_reverse_diffusion=not no_clip, device=device)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
recon_data.shape
# Out:
# torch.Size([128, 1, 28, 28])

# %%
plt.imshow(recon_data[0,0].detach().cpu().numpy())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 plt.imshow(recon_data[0,0].detach().cpu().numpy())
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
test_mse(model_ema.module, test_loader, device)
# Out:
# Reconstruct:   5%|▍         | 49/1000 [00:03<01:11, 13.30it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 test_mse(model_ema.module, test_loader, device)
#
# Cell In[92], line 10, in test_mse(model, test_loader, device, name)
#       8         noise = torch.randn_like(data).to(device)
#       9         pred_noise = model(data, noise)
# ---> 10         recon_data = reconstruct_from_noise(model, batch_size, pred_noise, noise, clipped_reverse_diffusion=not no_clip, device=device)
#      11         test_loss += loss_function(recon_data, data).item()
#      13 test_loss /= len(test_loader.dataset)
#
# Cell In[90], line 10, in reconstruct_from_noise(model, batch_size, start_noise, noise, timesteps, clipped_reverse_diffusion, device)
#       8         x_t=model._reverse_diffusion_with_clip(x_t, t, noise)
#       9     else:
# ---> 10         x_t=model._reverse_diffusion(x_t, t, noise)
#      12 x_t=(x_t+1.)/2. #[-1,1] to [0,1]
#      14 return x_t
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/MNISTDiffusion-main/model.py:81, in MNISTDiffusion._reverse_diffusion(self, x_t, t, noise)
#      78 mean=(1./torch.sqrt(alpha_t))*(x_t-((1.0-alpha_t)/sqrt_one_minus_alpha_cumprod_t)*pred)
#      80 if t.min()>0:
# ---> 81     alpha_t_cumprod_prev=self.alphas_cumprod.gather(-1,t-1).reshape(x_t.shape[0],1,1,1)
#      82     std=torch.sqrt(beta_t*(1.-alpha_t_cumprod_prev)/(1.-alpha_t_cumprod))
#      83 else:
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1601, in Module.__getattr__(self, name)
#    1598     if '_backward_pre_hooks' not in self.__dict__:
#    1599         self._backward_pre_hooks = OrderedDict()
# -> 1601 def __getattr__(self, name: str) -> Union[Tensor, 'Module']:
#    1602     if '_parameters' in self.__dict__:
#    1603         _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:
