# %%
# %load_ext autoreload
# %autoreload 2

from __future__ import print_function
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
import matplotlib.pyplot as plt
import numpy as np
from functions import *

# %% [markdown]
# # VAE

# %% [markdown]
# ## 1) Train

# %% [markdown]
# ### Define hyperparams

# %%
batch_size = 128
log_interval = 10
epochs = 10
torch.manual_seed(1)

use_cuda = True if torch.cuda.is_available() else False
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %% [markdown]
# ### Load train and test data

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.ToTensor()),
    batch_size=batch_size, shuffle=True, **kwargs)

# %% [markdown]
# ### Define model

# %%
model = VAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# ### Train & test

# %%
for epoch in range(1, epochs + 1):
    model = train(epoch, model, train_loader, optimizer, loss_function, device)
    test(epoch, model, test_loader, loss_function, batch_size, device, name='VAE')
    test(epoch, model, test_loader, loss_function_continuous, batch_size, device, name='VAE_CBVAE')
# Out:
# torch.Size([])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 142.269424
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 139.660080
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 141.666290
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 148.927597
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 140.252869
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 142.555084
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 142.230682
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 140.778091
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 144.487564
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 137.420670
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 146.560562
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [14080/60000 (23%)]	Loss: 142.730927
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 143.155365
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [16640/60000 (28%)]	Loss: 147.221863
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [17920/60000 (30%)]	Loss: 145.005814
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 151.773819
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 147.467880
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [21760/60000 (36%)]	Loss: 144.131653
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [23040/60000 (38%)]	Loss: 144.034927
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [24320/60000 (41%)]	Loss: 152.444366
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 141.198257
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [26880/60000 (45%)]	Loss: 149.305069
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [28160/60000 (47%)]	Loss: 146.911697
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [29440/60000 (49%)]	Loss: 148.005966
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 143.030502
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 146.400162
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [33280/60000 (55%)]	Loss: 143.949966
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [34560/60000 (58%)]	Loss: 144.379944
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 141.147354
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [37120/60000 (62%)]	Loss: 147.703888
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 139.618378
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [39680/60000 (66%)]	Loss: 152.497009
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 142.602646
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [42240/60000 (70%)]	Loss: 140.750275
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [43520/60000 (72%)]	Loss: 145.325180
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 137.744766
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 for epoch in range(1, epochs + 1):
# ----> 2     model = train(epoch, model, train_loader, optimizer, loss_function, device)
#       3     test(epoch, model, test_loader, loss_function, batch_size, device, name='VAE')
#       4     test(epoch, model, test_loader, loss_function_continuous, batch_size, device, name='VAE_CBVAE')
#
# File ~/Spaces/Education/00.KU/PML2023/Exercises/assignments/exam/functions.py:18, in train(epoch, model, train_loader, optimizer, loss_function, device, log_interval)
#      16 data = data.to(device)
#      17 optimizer.zero_grad()
# ---> 18 recon_batch, mu, logvar = model(data)
#      19 loss = loss_function(recon_batch, data, mu, logvar)
#      20 loss.backward()
#
# File ~/.miniconda/envs/pyro/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.miniconda/envs/pyro/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Spaces/Education/00.KU/PML2023/Exercises/assignments/exam/functions.py:99, in VAE.forward(self, x)
#      97 mu, logvar = self.encode(x.view(-1, 784))
#      98 z = self.reparameterize(mu, logvar)
# ---> 99 return self.decode(z), mu, logvar
#
# File ~/Spaces/Education/00.KU/PML2023/Exercises/assignments/exam/functions.py:94, in VAE.decode(self, z)
#      92 h3 = F.relu(self.fc3(z))
#      93 h4 = F.relu(self.fc3a(h3))
# ---> 94 return torch.sigmoid(self.fc4(h4))
#
# KeyboardInterrupt:

# %%
test_mse(model, test_loader, device, name='VAE_MSE')
# Out:
# ====> VAE_MSE Test set loss: 0.0003

# %% [markdown]
# ### Plot

# %%
test_data = list(test_loader)
test_sample_num = len(test_data)
results = []
groups = torch.empty(0)
j = 0
for i in range(test_sample_num):
    labels = test_data[i][1]
    groups = torch.cat((groups, labels))
    
    images = test_data[i][0]
    K = images.shape[0]
    for k in range(K):
        img = images[k,:,:,:]
        img = torch.flatten(img)
        mean_img = model.encode(img)[0] # X,Y
        results.append(mean_img.detach().numpy())
        j +=1

results = np.array(results)

# %%
scatter_x = results[:,0]
scatter_y = results[:,1]
colors = ['green', 'blue', 'red', 'cyan', 'purple', 'magenta', 'brown', 'orange', 'yellow', 'black']

fig, ax = plt.subplots()
for g in np.unique(groups):
    g = int(g)
    idx = np.where(groups == g)
    ax.scatter(scatter_x[idx], scatter_y[idx], c=colors[g], label=g, s=1)
    
ax.legend()
plt.savefig('figs/A/VAE_2D_Latentspace.png')
plt.show()

# %% [markdown]
# ## 2) We continue the latent space investigation by evaluating possible outcomes of p(z). As a means to do that, we revisit the inverse Gassian CDF and uniformly distributed samples and its map to a random Normal distribution.: Create a 2D grid of size (k,k) (e.g. torch.linspace, torch.meshgrid) and map through torch.distributions.normal.Normal.icdf to get equally spaced points according to the Gaussian CDF. Create a k,k figure for each entry and plot an image of p(x|z).

# %%
M = 10
x = torch.linspace(start=0, end=1, steps=M+2)[:-1][1:]
mesh_x, mesh_y = torch.meshgrid(x, x)
gauss = torch.distributions.normal.Normal(loc = 0, scale = 1)
gauss_x = gauss.icdf(mesh_x)
gauss_y = gauss.icdf(mesh_y)

fig, ax = plt.subplots(nrows=M, ncols=M, figsize=(10, 10))
for i in range(M):
    for j in range(M):
        _x = gauss_x[i,j].item()
        _y = gauss_y[i,j].item()
        
        im = model.decode(torch.Tensor([_x, _y]))
        im = im.detach().numpy().reshape((28, 28))
        
        ax[i,j].imshow(im, cmap='gray')
        ax[i,j].axis('off')

plt.tight_layout()
plt.savefig('figs/A/VAE_GRID.png')
plt.show()

# %% [markdown]
# ### Sample from beta distribution

# %%
M = 10
x = torch.linspace(start=0, end=1, steps=M+2)[:-1][1:]
mesh_x, mesh_y = torch.meshgrid(x, x)
gauss_x = torch.distributions.beta.Beta(concentration1=mesh_x, concentration0=mesh_x).sample()
gauss_y = torch.distributions.beta.Beta(concentration1=mesh_y, concentration0=mesh_y).sample()

fig, ax = plt.subplots(nrows=M, ncols=M, figsize=(10, 10))
for i in range(M):
    for j in range(M):
        _x = gauss_x[i,j].item()
        _y = gauss_y[i,j].item()
        
        im = model.decode(torch.Tensor([_x, _y]))
        im = im.detach().numpy().reshape((28, 28))
        
        ax[i,j].imshow(im, cmap='gray')
        ax[i,j].axis('off')

plt.tight_layout()
plt.savefig('figs/A/VAE_GRID_BETA.png')
plt.show()
